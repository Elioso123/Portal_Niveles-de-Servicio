# %% [markdown]
# <a href="https://colab.research.google.com/github/Elioso123/Portal_Niveles-de-Servicio/blob/main/Analisis_sla_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from time import time
rtiempo_inicial = time()

# %%
#Conexión de Colab a GSheets.
# !pip install gspread
import gspread_dataframe as gd

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

#from oauth2client.client import GoogleCredentials
#gc = gs.authorize(GoogleCredentials.get_application_default())

# %%
#Asigar variables a rutas de archivos, se acota solo a 2021 para agilizar el cálculo
'''
#file1="/content/drive/MyDrive/PORTAL_INTERNO_SLA/Q1_2020.xlsx"
#file2="/content/drive/MyDrive/PORTAL_INTERNO_SLA/Q2_2020.xlsx"
#file3="/content/drive/MyDrive/PORTAL_INTERNO_SLA/Q3_2020.xlsx"
#file4="/content/drive/MyDrive/PORTAL_INTERNO_SLA/Q4_2020.xlsx"
'''
# file5="/content/drive/MyDrive/PORTAL_INTERNO_SLA/01_2021.xlsx"
# file6="/content/drive/MyDrive/PORTAL_INTERNO_SLA/02_2021.xlsx"
# file7="/content/drive/MyDrive/PORTAL_INTERNO_SLA/03_2021.xlsx"
# file8="/content/drive/MyDrive/PORTAL_INTERNO_SLA/04_2021.xlsx"
# file9="/content/drive/MyDrive/PORTAL_INTERNO_SLA/05_2021.xlsx"
# file10="/content/drive/MyDrive/PORTAL_INTERNO_SLA/06_2021.xlsx"

#f1 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/01-06_2021.xlsx"
#f2 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/07_2021.xlsx"
#f3 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/08_2021.xlsx"
#f4 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/09_2021.xlsx"
#f5 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/10_2021.xlsx"
#f6 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/11_2021.xlsx"
#f7 ="/content/drive/MyDrive/PORTAL_INTERNO_SLA/12_2021.xlsx"

#-----------------------2022-------------#

#f8 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/01_2022.xlsx"
#f9 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/02_2022.xlsx"
#f10 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/03_2022.xlsx"
#f11 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/04_2022.xlsx"
#f12 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/05_2022.xlsx"  # Para el mes de mayo quitar signo de gato del principio
#f13 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/06_2022.xlsx" # Para el mes de junio quitar signo de gato del principio
#f14 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/07_2022.xlsx" # Para el mes de julio quitar signo de gato del principio
#f15 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/08_2022.xlsx" # Para el mes de julio quitar signo de gato del principio
#f16 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/09_2022.xlsx" # Para el mes de julio quitar signo de gato del principio
#f17 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/10_2022.xlsx" # Para el mes de julio quitar signo de gato del principio
#f18 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/11_2022.xlsx" # Para el mes de julio quitar signo de gato del principio
#f19 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/12_2022.xlsx" # Para el mes de julio quitar signo de gato del principio

#-----------------------2023-------------#

#f20 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/01_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
#f21 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/02_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
#f22 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/03_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
#f23 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/04_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f24 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/05_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f25 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/06_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f26 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/07_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f27 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/08_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f28 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/09_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f29 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/10_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f30 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/11_2023.xlsx" # Para el mes de julio quitar signo de gato del principio
f31 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/12_2023.xlsx" # Para el mes de julio quitar signo de gato del principio

#-----------------------2024-------------#

f32 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/01_2024.xlsx"
f33 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/02_2024.xlsx"
f34 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/03_2024.xlsx"
f35 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/04_2024.xlsx"
f36 = "/content/drive/MyDrive/PORTAL_INTERNO_SLA/05_2024.xlsx"

# %%
# !pip install openpyxl --upgrade --pre

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Leer archivos en DFs
'''
#Q1 = pd.read_excel(file1)
#Q2 = pd.read_excel(file2)
#Q3 = pd.read_excel(file3)
#Q4 = pd.read_excel(file4)
'''
# M1 = pd.read_excel(file5)
# M2 = pd.read_excel(file6)
# M3 = pd.read_excel(file7)
# M4 = pd.read_excel(file8)
# M5 = pd.read_excel(file9)
# M6 = pd.read_excel(file10)
#df_01_06 = pd.read_excel(f1)
#df_07 = pd.read_excel(f2)
#df_08 = pd.read_excel(f3)
#df_09 = pd.read_excel(f4)
#df_10 = pd.read_excel(f5)
#df_11 = pd.read_excel(f6)
#df_12 = pd.read_excel(f7)

#------------2022----------------------#

#df_012022 = pd.read_excel(f8)
#df_022022 = pd.read_excel(f9)
#df_032022 = pd.read_excel(f10)
#df_042022 = pd.read_excel(f11)
#df_052022 = pd.read_excel(f12) # Para el mes de mayo quitar signo de gato del principio
#df_062022 = pd.read_excel(f13) # Para el mes de junio quitar signo de gato del principio
#df_072022 = pd.read_excel(f14) # Para el mes de julio quitar signo de gato del principio
#df_082022 = pd.read_excel(f15) # Para el mes de julio quitar signo de gato del principio
#df_092022 = pd.read_excel(f16) # Para el mes de julio quitar signo de gato del principio
#df_102022 = pd.read_excel(f17) # Para el mes de julio quitar signo de gato del principio
#df_112022 = pd.read_excel(f18) # Para el mes de julio quitar signo de gato del principio
#df_122022 = pd.read_excel(f19) # Para el mes de julio quitar signo de gato del principio

#------------2023----------------------#

#df_012023 = pd.read_excel(f20)
#df_022023 = pd.read_excel(f21)
#df_032023 = pd.read_excel(f22)
#df_042023 = pd.read_excel(f23)
df_052023 = pd.read_excel(f24)
df_062023 = pd.read_excel(f25)
df_072023 = pd.read_excel(f26)
df_082023 = pd.read_excel(f27)
df_092023 = pd.read_excel(f28)
df_102023 = pd.read_excel(f29)
df_112023 = pd.read_excel(f30)
df_122023 = pd.read_excel(f31)

#------------2024----------------------#

df_012024 = pd.read_excel(f32)
df_022024 = pd.read_excel(f33)
df_032024 = pd.read_excel(f34)
df_042024 = pd.read_excel(f35)
df_052024 = pd.read_excel(f36)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Tabla de conciliaciones en GSheets
df_conciliacion = gc.open('Conciliaciones').worksheet("Conciliacion")
df_conciliacion = df_conciliacion.get_all_records(head=1)
df_conciliacion = pd.DataFrame(df_conciliacion)

# %%
df_conciliacion['TIEMPO_FALLA_TPE'] = pd.to_timedelta(df_conciliacion['TIEMPO_FALLA_TPE'])
df_conciliacion['TIEMPO_FALLA_CTE'] = pd.to_timedelta(df_conciliacion['TIEMPO_FALLA_CTE'])
df_conciliacion['TIEMPO_FALLA_PROVEEDOR'] = pd.to_timedelta(df_conciliacion['TIEMPO_FALLA_PROVEEDOR'])
df_conciliacion['TIEMPO_FALLA_TERCEROS'] = pd.to_timedelta(df_conciliacion['TIEMPO_FALLA_TERCEROS'])
df_conciliacion['FECHA_INICIO'] = pd.to_datetime(df_conciliacion['FECHA_INICIO'], dayfirst=True)
df_conciliacion['FECHA_HORA_NOTIF_SOLUCION'] = pd.to_datetime(df_conciliacion['FECHA_HORA_NOTIF_SOLUCION'], dayfirst=True)
df_conciliacion['FECHA_CIERRE'] = pd.to_datetime(df_conciliacion['FECHA_CIERRE'], dayfirst=True)

# %%
df_conciliacion.dtypes
# Out:
# REF_NUM                                int64
# CLIENTE_CI                            object
# CLIENTE_CMDB                          object
# FECHA_INICIO                  datetime64[ns]
# FECHA_HORA_NOTIF_SOLUCION     datetime64[ns]
# FECHA_CIERRE                  datetime64[ns]
# TIEMPO_FALLA_CTE             timedelta64[ns]
# TIEMPO_FALLA_TPE             timedelta64[ns]
# TIEMPO_FALLA_PROVEEDOR       timedelta64[ns]
# TIEMPO_FALLA_TERCEROS        timedelta64[ns]
# DIAGNOSTICO                           object
# SOLUCION                              object
# RESPONSABLE                           object
# AFECTACION_DE_SERVICIO                object
# CONCILIADOR                           object
# MOTIVO                                object
# Cliente                               object
# dtype: object

# %%
#Concatenar DFs en base master, agregar los meses nuevos agregados a la base master
#df_master = pd.concat([Q1, Q2, Q3, Q4, M1, M2, M3, M4, M5, M6, M7, M8, M9])
df_master = pd.concat([df_052023, df_062023, df_072023, df_082023, df_092023, df_102023, df_112023, df_122023, df_012024, df_022024, df_032024, df_042024, df_052024]) #Agregar meses nuevos separados por comas
df_master= df_master.rename(columns={'REF_NUN': 'REF_NUM'})

# %%
#df_sitios_corregir = df_sitios_corregir.get_all_records(head=1)
#df_sitios_corregir = pd.DataFrame(df_sitios_corregir)
#df_082022.loc[df_082022['REF_NUM'] == '1547400']

# %%
#Contar total de registros en DF_master concatenados
#Q1.REF_NUM.count() + Q2.REF_NUM.count() + Q3.REF_NUM.count() + Q4.REF_NUM.count() + M1.REF_NUM.count() + M2.REF_NUM.count() + M3.REF_NUM.count() + M4.REF_NUM.count() + M5.REF_NUM.count()
# M1.REF_NUM.count() + M2.REF_NUM.count() + M3.REF_NUM.count() + M4.REF_NUM.count() + M5.REF_NUM.count() + M6.REF_NUM.count()
df_052023.REF_NUN.count() + df_062023.REF_NUN.count() + df_072023.REF_NUN.count() + df_082023.REF_NUN.count() + df_092023.REF_NUN.count() + df_102023.REF_NUN.count() + df_112023.REF_NUN.count() + df_122023.REF_NUN.count() + df_012024.REF_NUN.count() + df_022024.REF_NUN.count()+ df_032024.REF_NUN.count()+ df_042024.REF_NUN.count()+ df_052024.REF_NUN.count()
# Out:
# 409140

# %%
#Reemplaza valores "NAN" por NULL, Ceros, etc..
df_master.TIEMPO_FALLA_CTE.fillna("00:00:00", inplace=True)
df_master.TIEMPO_FALLA_TPE.fillna("00:00:00", inplace=True)
df_master.TIEMPO_FALLA_PROVEEDOR.fillna("00:00:00", inplace=True)
df_master.TIEMPO_FALLA_TERCEROS.fillna("00:00:00", inplace=True)
df_master.TIEMPO_ACTIVIDAD.fillna("00:00:00", inplace=True)
df_master.DIAGNOSTICO.fillna('SIN INFORMACIÓN', inplace=True)
df_master.SOLUCION.fillna('SIN INFORMACIÓN', inplace=True)
df_master.CLIENTE_CI.fillna('NULL', inplace=True)
df_master.CLIENTE_CMDB.fillna('NULL', inplace=True)
df_master.AFECTACION_DE_SERVICIO.fillna('SI', inplace=True)
df_master.replace('', np.nan, inplace=True)
df_master.head()
# Out:
#    REF_NUM                                           NOMBRE  \
# 0  1455991  Integracion_SalesForce Integracion_SalesForce
# 1  1459812  Integracion_SalesForce Integracion_SalesForce
# 2  1499458  Integracion_SalesForce Integracion_SalesForce
# 3  1765007                            Garcia Bonilla Ivan
# 4  1791272                          González Barona David
#
#   ZES_PROACTIVO_REACTIVO SERVICIO_AFECTADO            FALLA  ESTATUS MOTIVO  \
# 0               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 1               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 2               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 3              PROACTIVO               LAN         Internet  Cerrado    NaN
# 4               REACTIVO               LAN  Videovigilancia  Cerrado    NaN
#
#               GRUPO_ACTUAL PRIORIDAD         FECHA_INICIO  ...  \
# 0       NOC TPE SOPORTE N1   3-Media  2022-05-20 13:20:53  ...
# ...

# %%
# Mapeo de columnas CLIENTE_CI y CLIENTE_CMDB

df_sitios_corregir = gc.open('CAT_SITIOS_SUSTITUIR').worksheet("sitios_corregir")

df_sitios_corregir = df_sitios_corregir.get_all_records(head=1)
df_sitios_corregir = pd.DataFrame(df_sitios_corregir)
##df_sitios_corregir.dtypes
## Obtener la vertical de catalogo y agregarla a df_master
##df_master = pd.merge(df_master, df_sitios_corregir.loc[:, ['CLIENTE_CI','cliente_correcto_cat']], how='left', on= ['CLIENTE_CI'])
df_master = pd.merge(df_master, df_sitios_corregir.loc[:, ['CLIENTE_CMDB','sitio_correcto_cat','cliente_correcto_cat']], how='left', on= ['CLIENTE_CMDB'])

df_master['cliente_correcto_cat'] = df_master['cliente_correcto_cat'].replace([np.nan], [df_master['CLIENTE_CI']])
df_master['sitio_correcto_cat'] = df_master['sitio_correcto_cat'].replace([np.nan], [df_master['CLIENTE_CMDB']])
### Asignar valores correctos a columnas llave
df_master['CLIENTE_CMDB'] = df_master['sitio_correcto_cat'] #cambio
df_master['CLIENTE_CI'] = df_master['cliente_correcto_cat']
### Eliminar columnas de apoyo
df_master.drop(['cliente_correcto_cat'], axis=1)
df_master.drop(['sitio_correcto_cat'], axis=1)
##df_master['CLIENTE_CMDB'].head
df_master.count()
# Out:
# REF_NUM                              427791
# NOMBRE                               427791
# ZES_PROACTIVO_REACTIVO               219144
# SERVICIO_AFECTADO                    331224
# FALLA                                427728
# ESTATUS                              427791
# MOTIVO                                 1905
# GRUPO_ACTUAL                         427054
# PRIORIDAD                            427791
# FECHA_INICIO                         427791
# FECHA_HORA_NOTIF_SOLUCION            385778
# FECHA_CIERRE                         427791
# DURACION                             385778
# DIAGNOSTICO                          427791
# SOLUCION                             427791
# AREA_RESOLUTORA                      275092
# TIEMPO_FALLA_CTE                     427791
# TIEMPO_FALLA_TPE                     427791
# AFECTACION_DE_SERVICIO               427791
# RESUMEN                              427791
# DESCRIPCION                          427791
# ...

# %%
 #Tipos de datos asignados por default
df_master.dtypes
# Out:
# REF_NUM                                int64
# NOMBRE                                object
# ZES_PROACTIVO_REACTIVO                object
# SERVICIO_AFECTADO                     object
# FALLA                                 object
# ESTATUS                               object
# MOTIVO                                object
# GRUPO_ACTUAL                          object
# PRIORIDAD                             object
# FECHA_INICIO                          object
# FECHA_HORA_NOTIF_SOLUCION             object
# FECHA_CIERRE                          object
# DURACION                              object
# DIAGNOSTICO                           object
# SOLUCION                              object
# AREA_RESOLUTORA                       object
# TIEMPO_FALLA_CTE                      object
# TIEMPO_FALLA_TPE                      object
# AFECTACION_DE_SERVICIO                object
# RESUMEN                               object
# DESCRIPCION                           object
# ...

# %%
#Normalizar sintaxis y tipos de datos para cálculos
df_master['TIEMPO_FALLA_CTE']= pd.to_timedelta(df_master['TIEMPO_FALLA_CTE'])
df_master['TIEMPO_FALLA_TPE']= pd.to_timedelta(df_master['TIEMPO_FALLA_TPE'])
df_master['TIEMPO_FALLA_PROVEEDOR']= pd.to_timedelta(df_master['TIEMPO_FALLA_PROVEEDOR'])
df_master['TIEMPO_FALLA_TERCEROS']= pd.to_timedelta(df_master['TIEMPO_FALLA_TERCEROS'])
#df_master['TIEMPO_FALLA_PROVEEDOR'] = pd.to_timedelta(pd.to_datetime(df_master['TIEMPO_FALLA_PROVEEDOR']).dt.strftime('%H:%M:%S'))
#df_master['TIEMPO_FALLA_TERCEROS'] = pd.to_timedelta(pd.to_datetime(df_master['TIEMPO_FALLA_TERCEROS']).dt.strftime('%H:%M:%S'))
df_master['FECHA_INICIO'] = pd.to_datetime(df_master['FECHA_INICIO'], dayfirst=True)
df_master['FECHA_HORA_NOTIF_SOLUCION'] = pd.to_datetime(df_master['FECHA_HORA_NOTIF_SOLUCION'], dayfirst=True)
df_master['FECHA_CIERRE'] = pd.to_datetime(df_master['FECHA_CIERRE'], dayfirst=True)
df_master['AÑO'] = df_master['FECHA_CIERRE'].dt.year
df_master['MES'] = df_master['FECHA_CIERRE'].dt.month
df_master['SEMANA'] = df_master['FECHA_CIERRE'].dt.isocalendar().week
df_master['DIA'] = df_master['FECHA_CIERRE'].dt.day
df_master['HORA'] = df_master['FECHA_CIERRE'].dt.hour
df_master.index = df_master.index + 1
df_master = df_master.drop_duplicates()

# %%
df_master.REF_NUM.count()
# Out:
# 409665

# %%
df_cat_tip = gc.open('Catalogo de Tipificaciones').worksheet("Cliente")
df_cat_tip = df_cat_tip.get_all_records(head=1)
df_cat_tip = pd.DataFrame(df_cat_tip)

# %%
df_cat_tip.head()
# Out:
#                                            Solución         Categoria  \
# 0                     Se envia evidencia al cliente  Asesoría técnica
# 1     Cliente debe reportar con su DNS autoritativo  Asesoría técnica
# 2  Cliente debe validar que el dominio sea correcto  Asesoría técnica
# 3                                  ASESORIA TECNICA  Asesoría técnica
# 4                   Asesoría de servicio al cliente  Asesoría técnica
#
#   Imputable Responsable                            Diagnóstico
# 0   Cliente     Cliente              Cliente.Saturación del BW
# 1   Cliente     Cliente         Cliente.Desconexión de equipos
# 2   Cliente     Cliente                   IMPUTABLE AL CLIENTE
# 3   Cliente     Cliente  Manipulación física imputable cliente
# 4   Cliente     Cliente          Cliente. Configuración logica

# %%
#Regla de Negocio 1: Encontrar Palabra "Cliente", dentro de 3 variables. Cuando sea True Responsable "Cliente", cuando sea "False", reponsable "Totalplay"
df_master["RESPONSABLE"] = np.where(df_master['SOLUCION'].isin(df_cat_tip['Solución']), True, False)
#df_master["RESPONSABLE"] = np.where(df_master['DIAGNOSTICO'].isin(df_cat_tip['Diagnóstico']), True, False)
df_master["RESPONSABLE"] = np.where(df_master['RESPONSABLE']==False, (df_master['DIAGNOSTICO'].str.contains(r'(?i)\w*cliente\w*') & df_master['SOLUCION'].str.contains(r'(?i)\w*cliente\w*')), df_master["RESPONSABLE"])
df_master["RESPONSABLE"] = np.where(df_master['RESPONSABLE']==False, (df_master['DIAGNOSTICO'].str.contains(r'(?i)\w*cliente\w*') & df_master['AREA_RESOLUTORA'].str.contains(r'(?i)\w*cliente\w*')), df_master["RESPONSABLE"])
df_master["RESPONSABLE"] = np.where(df_master['RESPONSABLE']==False, (df_master['SOLUCION'].str.contains(r'(?i)\w*cliente\w*') & df_master['AREA_RESOLUTORA'].str.contains(r'(?i)\w*cliente\w*')), df_master["RESPONSABLE"])

# %%
df_master.dtypes
# Out:
# REF_NUM                                        int64
# NOMBRE                                        object
# ZES_PROACTIVO_REACTIVO                        object
# SERVICIO_AFECTADO                             object
# FALLA                                         object
# ESTATUS                                       object
# MOTIVO                                        object
# GRUPO_ACTUAL                                  object
# PRIORIDAD                                     object
# FECHA_INICIO                          datetime64[ns]
# FECHA_HORA_NOTIF_SOLUCION             datetime64[ns]
# FECHA_CIERRE                          datetime64[ns]
# DURACION                                      object
# DIAGNOSTICO                                   object
# SOLUCION                                      object
# AREA_RESOLUTORA                               object
# TIEMPO_FALLA_CTE                     timedelta64[ns]
# TIEMPO_FALLA_TPE                     timedelta64[ns]
# ...

# %%
#df_master.groupby(['CLIENTE_CI','RESPONSABLE','SOLUCION'])['REF_NUM'].count().reset_index().to_csv('CLIENTE_SOLUCION_RESP.csv', encoding='latin-1', index=False)

# %%
df_master.RESPONSABLE = df_master.RESPONSABLE.replace({True: "CLIENTE", False: "TOTALPLAY"})

# %%
#Agrupar fallas del cliente para su análisis
cat_fallas_cliente = df_master.groupby(['DIAGNOSTICO','SOLUCION','AREA_RESOLUTORA','RESPONSABLE'])['REF_NUM'].count().reset_index()
cat_fallas_cliente = cat_fallas_cliente.sort_values('REF_NUM', ascending=False)
cat_fallas_cliente.to_csv('analisis_cliente_fallas.csv', encoding='latin-1')

# %%
df_reg_ori = df_master.loc[df_master['REF_NUM'].isin(df_conciliacion.REF_NUM)]
df_reg_ori = df_reg_ori[['REF_NUM','FECHA_INICIO','FECHA_HORA_NOTIF_SOLUCION','FECHA_CIERRE','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','DIAGNOSTICO','SOLUCION','RESPONSABLE','AFECTACION_DE_SERVICIO','CLIENTE_CI','CLIENTE_CMDB']]
df_reg_ori['TIEMPO_FALLA_CTE'] = df_reg_ori['TIEMPO_FALLA_CTE'].dt.total_seconds()
df_reg_ori['TIEMPO_FALLA_TPE'] = df_reg_ori['TIEMPO_FALLA_TPE'].dt.total_seconds()
df_reg_ori['TIEMPO_FALLA_PROVEEDOR'] = df_reg_ori['TIEMPO_FALLA_PROVEEDOR'].dt.total_seconds()
df_reg_ori['TIEMPO_FALLA_TERCEROS'] = df_reg_ori['TIEMPO_FALLA_TERCEROS'].dt.total_seconds()
df_reg_ori['RESPONSABLE']= df_reg_ori.RESPONSABLE.replace({True: "CLIENTE", False: "TOTALPLAY"})
df_reg_ori = df_reg_ori.sort_values('REF_NUM', ascending=True)
df_reg_ori.count()
# Out:
# REF_NUM                      2016
# FECHA_INICIO                 2016
# FECHA_HORA_NOTIF_SOLUCION    2016
# FECHA_CIERRE                 2016
# TIEMPO_FALLA_CTE             2016
# TIEMPO_FALLA_TPE             2016
# TIEMPO_FALLA_PROVEEDOR       2016
# TIEMPO_FALLA_TERCEROS        2016
# DIAGNOSTICO                  2016
# SOLUCION                     2016
# RESPONSABLE                  2016
# AFECTACION_DE_SERVICIO       2016
# CLIENTE_CI                   2016
# CLIENTE_CMDB                 2016
# dtype: int64

# %%
#Actualizar registros conciliados.
df_master=df_master.set_index('REF_NUM')
df_master.update(df_conciliacion.set_index('REF_NUM'))
df_master.reset_index(inplace=True)
df_master = df_master.drop_duplicates()

df_master_v2 = df_master.drop(['DESCRIPCION', 'IP_CMDB', 'RESPONSABLE', 'SEMANA', 'DIA', 'HORA'], axis=1)
df_master_v2['AÑO'] = df_master_v2['FECHA_CIERRE'].dt.year
df_master_v2['MES'] = df_master_v2['FECHA_CIERRE'].dt.month
df_master_v2['TIEMPO_FALLA_CTE'] = df_master_v2['TIEMPO_FALLA_CTE'].dt.total_seconds()
df_master_v2['TIEMPO_FALLA_PROVEEDOR'] = df_master_v2['TIEMPO_FALLA_PROVEEDOR'].dt.total_seconds()
df_master_v2['TIEMPO_FALLA_TERCEROS'] = df_master_v2['TIEMPO_FALLA_TERCEROS'].dt.total_seconds()
df_master_v2['TIEMPO_FALLA_TPE'] = df_master_v2['TIEMPO_FALLA_TPE'].dt.total_seconds()
df_master_v2 = df_master_v2.drop_duplicates()

# df_master_01 = df_master_v2[(df_master_v2['MES']==1) & (df_master_v2['AÑO']==2021)]
# df_master_01 = df_master_01.drop(['MES','AÑO'], axis=1)
# df_master_02 = df_master_v2[(df_master_v2['MES']==2) & (df_master_v2['AÑO']==2021)]
# df_master_02 = df_master_02.drop(['MES','AÑO'], axis=1)
# df_master_03 = df_master_v2[(df_master_v2['MES']==3) & (df_master_v2['AÑO']==2021)]
# df_master_03 = df_master_03.drop(['MES','AÑO'], axis=1)
# df_master_04 = df_master_v2[(df_master_v2['MES']==4) & (df_master_v2['AÑO']==2021)]
# df_master_04 = df_master_04.drop(['MES','AÑO'], axis=1)
# df_master_05 = df_master_v2[(df_master_v2['MES']==5) & (df_master_v2['AÑO']==2021)]
# df_master_05 = df_master_05.drop(['MES','AÑO'], axis=1)
# df_master_06 = df_master_v2[(df_master_v2['MES']==6) & (df_master_v2['AÑO']==2021)]
# df_master_06 = df_master_06.drop(['MES','AÑO'], axis=1)
# df_master_07 = df_master_v2[(df_master_v2['MES']==7) & (df_master_v2['AÑO']==2021)]
# df_master_07 = df_master_07.drop(['MES','AÑO'], axis=1)
# df_master_08 = df_master_v2[(df_master_v2['MES']==8) & (df_master_v2['AÑO']==2021)]
# df_master_08 = df_master_08.drop(['MES','AÑO'], axis=1)
# df_master_09 = df_master_v2[(df_master_v2['MES']==9) & (df_master_v2['AÑO']==2021)]
# df_master_09 = df_master_09.drop(['MES','AÑO'], axis=1)
# df_master_10 = df_master_v2[(df_master_v2['MES']==10) & (df_master_v2['AÑO']==2021)]
# df_master_10 = df_master_10.drop(['MES','AÑO'], axis=1)
# df_master_11 = df_master_v2[(df_master_v2['MES']==11) & (df_master_v2['AÑO']==2021)]
# df_master_11 = df_master_11.drop(['MES','AÑO'], axis=1)
#df_master_12 = df_master_v2[(df_master_v2['MES']==12) & (df_master_v2['AÑO']==2021)]
#df_master_12 = df_master_12.drop(['MES','AÑO'], axis=1)

#-------------2022--------------#
# df_master_012022 = df_master_v2[(df_master_v2['MES']==1) & (df_master_v2['AÑO']==2022)]
# df_master_012022 = df_master_012022.drop(['MES','AÑO'], axis=1)

# df_master_022022 = df_master_v2[(df_master_v2['MES']==2) & (df_master_v2['AÑO']==2022)]
# df_master_022022 = df_master_022022.drop(['MES','AÑO'], axis=1)

# df_master_032022 = df_master_v2[(df_master_v2['MES']==3) & (df_master_v2['AÑO']==2022)]
# df_master_032022 = df_master_032022.drop(['MES','AÑO'], axis=1)

# df_master_042022 = df_master_v2[(df_master_v2['MES']==4) & (df_master_v2['AÑO']==2022)]
# df_master_042022 = df_master_042022.drop(['MES','AÑO'], axis=1)

# df_master_052022 = df_master_v2[(df_master_v2['MES']==5) & (df_master_v2['AÑO']==2022)]
# df_master_052022 = df_master_052022.drop(['MES','AÑO'], axis=1)

# df_master_062022 = df_master_v2[(df_master_v2['MES']==6) & (df_master_v2['AÑO']==2022)]
# df_master_062022 = df_master_062022.drop(['MES','AÑO'], axis=1)

# df_master_072022 = df_master_v2[(df_master_v2['MES']==7) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
# df_master_072022 = df_master_072022.drop(['MES','AÑO'], axis=1)

# df_master_082022 = df_master_v2[(df_master_v2['MES']==8) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
# df_master_082022 = df_master_082022.drop(['MES','AÑO'], axis=1)

# df_master_092022 = df_master_v2[(df_master_v2['MES']==9) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
# df_master_092022 = df_master_092022.drop(['MES','AÑO'], axis=1)

# df_master_102022 = df_master_v2[(df_master_v2['MES']==10) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
# df_master_102022 = df_master_102022.drop(['MES','AÑO'], axis=1)

#df_master_112022 = df_master_v2[(df_master_v2['MES']==11) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
#df_master_112022 = df_master_112022.drop(['MES','AÑO'], axis=1)

#df_master_122022 = df_master_v2[(df_master_v2['MES']==12) & (df_master_v2['AÑO']==2022)] #agregar nuevo mes
#df_master_122022 = df_master_122022.drop(['MES','AÑO'], axis=1)

#-------------2023--------------#

#df_master_012023 = df_master_v2[(df_master_v2['MES']==1) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
#df_master_012023 = df_master_012023.drop(['MES','AÑO'], axis=1)

#df_master_022023 = df_master_v2[(df_master_v2['MES']==2) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
#df_master_022023 = df_master_022023.drop(['MES','AÑO'], axis=1)

#df_master_032023 = df_master_v2[(df_master_v2['MES']==3) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
#df_master_032023 = df_master_032023.drop(['MES','AÑO'], axis=1)

#df_master_042023 = df_master_v2[(df_master_v2['MES']==4) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
#df_master_042023 = df_master_042023.drop(['MES','AÑO'], axis=1)

df_master_052023 = df_master_v2[(df_master_v2['MES']==5) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_052023 = df_master_052023.drop(['MES','AÑO'], axis=1)

df_master_062023 = df_master_v2[(df_master_v2['MES']==6) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_062023 = df_master_062023.drop(['MES','AÑO'], axis=1)

df_master_072023 = df_master_v2[(df_master_v2['MES']==7) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_072023 = df_master_072023.drop(['MES','AÑO'], axis=1)

df_master_082023 = df_master_v2[(df_master_v2['MES']==8) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_082023 = df_master_082023.drop(['MES','AÑO'], axis=1)

df_master_092023 = df_master_v2[(df_master_v2['MES']==9) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_092023 = df_master_092023.drop(['MES','AÑO'], axis=1)

df_master_102023 = df_master_v2[(df_master_v2['MES']==10) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_102023 = df_master_102023.drop(['MES','AÑO'], axis=1)

df_master_112023 = df_master_v2[(df_master_v2['MES']==11) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_112023 = df_master_112023.drop(['MES','AÑO'], axis=1)

df_master_122023 = df_master_v2[(df_master_v2['MES']==12) & (df_master_v2['AÑO']==2023)] #agregar nuevo mes
df_master_122023 = df_master_122023.drop(['MES','AÑO'], axis=1)

#-------------2024--------------#

df_master_012024 = df_master_v2[(df_master_v2['MES']==1) & (df_master_v2['AÑO']==2024)] #agregar nuevo mes
df_master_012024 = df_master_012024.drop(['MES','AÑO'], axis=1)

df_master_022024 = df_master_v2[(df_master_v2['MES']==2) & (df_master_v2['AÑO']==2024)] #agregar nuevo mes
df_master_022024 = df_master_022024.drop(['MES','AÑO'], axis=1)

df_master_032024 = df_master_v2[(df_master_v2['MES']==3) & (df_master_v2['AÑO']==2024)] #agregar nuevo mes
df_master_032024 = df_master_032024.drop(['MES','AÑO'], axis=1)

df_master_042024 = df_master_v2[(df_master_v2['MES']==4) & (df_master_v2['AÑO']==2024)]
df_master_042024 = df_master_042024.drop(['MES','AÑO'], axis=1)

df_master_052024 = df_master_v2[(df_master_v2['MES']==5) & (df_master_v2['AÑO']==2024)]
df_master_052024 = df_master_052024.drop(['MES','AÑO'], axis=1)

# df_master_v2 = df_master_v2[(df_master_v2['MES']<=10) & (df_master_v2['AÑO']==2021)]
# df_master_v2 = df_master_v2.drop(['AÑO', 'MES'], axis=1)
#df_master_v2.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/concentrado_bd_sd_ene_oct_2021.csv', encoding='utf-8', index=False)
# df_master_01.to_csv('/content/drive/MyDrive/SD_ReportServer/01_2021.csv', encoding='utf-8', index=False)
# df_master_02.to_csv('/content/drive/MyDrive/SD_ReportServer/02_2021.csv', encoding='utf-8', index=False)
# df_master_03.to_csv('/content/drive/MyDrive/SD_ReportServer/03_2021.csv', encoding='utf-8', index=False)
# df_master_04.to_csv('/content/drive/MyDrive/SD_ReportServer/04_2021.csv', encoding='utf-8', index=False)
# df_master_05.to_csv('/content/drive/MyDrive/SD_ReportServer/05_2021.csv', encoding='utf-8', index=False)
# df_master_06.to_csv('/content/drive/MyDrive/SD_ReportServer/06_2021.csv', encoding='utf-8', index=False)
# df_master_07.to_csv('/content/drive/MyDrive/SD_ReportServer/07_2021.csv', encoding='utf-8', index=False)
#df_master_08.to_csv('/content/drive/MyDrive/SD_ReportServer/08_2021.csv', encoding='utf-8', index=False)
#df_master_09.to_csv('/content/drive/MyDrive/SD_ReportServer/09_2021.csv', encoding='utf-8', index=False)
#df_master_10.to_csv('/content/drive/MyDrive/SD_ReportServer/10_2021.csv', encoding='utf-8', index=False)
#df_master_11.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/11_2021.csv', encoding='utf-8', index=False)
#df_master_12.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/12_2021.csv', encoding='utf-8', index=False)
#df_master_012022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/01_2022.csv', encoding='utf-8', index=False)
#df_master_022022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/02_2022.csv', encoding='utf-8', index=False)
#df_master_032022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/03_2022.csv', encoding='utf-8', index=False)
#df_master_042022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/04_2022.csv', encoding='utf-8', index=False)
#df_master_052022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/05_2022.csv', encoding='utf-8', index=False)
#df_master_062022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/06_2022.csv', encoding='utf-8', index=False)
#df_master_072022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/07_2022.csv', encoding='utf-8', index=False)
#df_master_082022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/08_2022.csv', encoding='utf-8', index=False)
#df_master_092022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/09_2022.csv', encoding='utf-8', index=False)
#df_master_102022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/10_2022.csv', encoding='utf-8', index=False)
#df_master_112022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/11_2022.csv', encoding='utf-8', index=False)
#df_master_122022.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/12_2022.csv', encoding='utf-8', index=False)
#df_master_012023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/01_2023.csv', encoding='utf-8', index=False)
#df_master_022023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/02_2023.csv', encoding='utf-8', index=False)
#df_master_032023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/03_2023.csv', encoding='utf-8', index=False)
#df_master_042023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/04_2023.csv', encoding='utf-8', index=False)
df_master_052023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/05_2023.csv', encoding='utf-8', index=False)
df_master_062023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/06_2023.csv', encoding='utf-8', index=False)
df_master_072023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/07_2023.csv', encoding='utf-8', index=False)
df_master_082023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/08_2023.csv', encoding='utf-8', index=False)
df_master_092023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/09_2023.csv', encoding='utf-8', index=False)
df_master_102023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/10_2023.csv', encoding='utf-8', index=False)
df_master_112023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/11_2023.csv', encoding='utf-8', index=False)
df_master_122023.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/12_2023.csv', encoding='utf-8', index=False)
df_master_012024.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/01_2024.csv', encoding='utf-8', index=False)
df_master_022024.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/02_2024.csv', encoding='utf-8', index=False)
df_master_032024.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/03_2024.csv', encoding='utf-8', index=False)
df_master_042024.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/04_2024.csv', encoding='utf-8', index=False)
df_master_052024.to_csv('/content/drive/MyDrive/SD_ReportServer/2. Reporte Tickets Cerrados/04_2024.csv', encoding='utf-8', index=False)
#Actualizar por mes nuevo

# %%
#df_master_v2.dtypes

# %%
df_rep_week = pd.read_excel('/content/drive/MyDrive/PORTAL_INTERNO_SLA/bd_sd_week.xlsx')
df_rep_week.to_csv('/content/drive/MyDrive/SD_ReportServer/1. Reportes Semanales Ultimas 2 semanas/bd_sd_week.csv', index=False, encoding='utf-8')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#df_BL = pd.read_excel('/content/drive/MyDrive/PORTAL_INTERNO_SLA/BL.xlsx')
#df_BL = df_BL[(df_BL['ESTATUS'] != 'Cerrado')
#& (df_BL['ESTATUS'] != 'Cancelado')
#& (df_BL['ESTATUS'] != 'Cerrado y sin resolver')
#& (df_BL['ESTATUS'] != 'Resuelto')
#& (df_BL['NOMBRE_SITIO'] != 'Gateway Integracion')
#& (~df_BL['CLIENTE'].isnull())]
#df_BL.to_csv('/content/drive/MyDrive/SD_ReportServer/3. Reporte para Backlog/bd_sd_backlog.csv', index=False, encoding='utf-8')

# %%
#df_BL.groupby('ESTATUS')['ESTATUS'].count()

# %%
df_reg_mod = df_conciliacion.loc[df_conciliacion['REF_NUM'].isin(df_reg_ori.REF_NUM)]
df_reg_mod = df_reg_mod[['REF_NUM','FECHA_INICIO','FECHA_HORA_NOTIF_SOLUCION','FECHA_CIERRE','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','DIAGNOSTICO','SOLUCION','RESPONSABLE','AFECTACION_DE_SERVICIO','CONCILIADOR','MOTIVO']]
df_reg_mod['TIEMPO_FALLA_CTE'] = df_reg_mod['TIEMPO_FALLA_CTE'].dt.total_seconds()
df_reg_mod['TIEMPO_FALLA_TPE'] = df_reg_mod['TIEMPO_FALLA_TPE'].dt.total_seconds()
df_reg_mod['TIEMPO_FALLA_PROVEEDOR'] = df_reg_mod['TIEMPO_FALLA_PROVEEDOR'].dt.total_seconds()
df_reg_mod['TIEMPO_FALLA_TERCEROS'] = df_reg_mod['TIEMPO_FALLA_TERCEROS'].dt.total_seconds()
df_reg_mod = df_reg_mod.sort_values('REF_NUM', ascending=True)
df_reg_mod.count()
# Out:
# REF_NUM                      2006
# FECHA_INICIO                 2006
# FECHA_HORA_NOTIF_SOLUCION    2006
# FECHA_CIERRE                 2006
# TIEMPO_FALLA_CTE             2006
# TIEMPO_FALLA_TPE             2006
# TIEMPO_FALLA_PROVEEDOR       2006
# TIEMPO_FALLA_TERCEROS        2006
# DIAGNOSTICO                  2006
# SOLUCION                     2006
# RESPONSABLE                  2006
# AFECTACION_DE_SERVICIO       2006
# CONCILIADOR                  2006
# MOTIVO                       2006
# dtype: int64

# %%
df_master.groupby('AFECTACION_DE_SERVICIO')['REF_NUM'].count()
# Out:
# AFECTACION_DE_SERVICIO
# NO       575
# SI    409090
# Name: REF_NUM, dtype: int64

# %%
#Regla de Negocio 1: Encontrar Palabra "Cliente", dentro de 3 variables. Cuando sea True Responsable "Cliente", cuando sea "False", reponsable "Totalplay"
#df_master["RESPONSABLE"] = df_master['DIAGNOSTICO'].str.contains(r'(?i)\w*cliente\w*') | df_master['SOLUCION'].str.contains(r'(?i)\w*cliente\w*') | df_master['AREA_RESOLUTORA'].str.contains(r'(?i)\w*cliente\w*')

# %%
df_master[(df_master['RESPONSABLE'] ==True)].count()
# Out:
# REF_NUM                              0
# NOMBRE                               0
# ZES_PROACTIVO_REACTIVO               0
# SERVICIO_AFECTADO                    0
# FALLA                                0
# ESTATUS                              0
# MOTIVO                               0
# GRUPO_ACTUAL                         0
# PRIORIDAD                            0
# FECHA_INICIO                         0
# FECHA_HORA_NOTIF_SOLUCION            0
# FECHA_CIERRE                         0
# DURACION                             0
# DIAGNOSTICO                          0
# SOLUCION                             0
# AREA_RESOLUTORA                      0
# TIEMPO_FALLA_CTE                     0
# TIEMPO_FALLA_TPE                     0
# AFECTACION_DE_SERVICIO               0
# RESUMEN                              0
# DESCRIPCION                          0
# TICKET_SISTEMA_EXTERNO               0
# REGION_CIUDAD                        0
# TICKET_PADRE                         0
# ...

# %%
#df_master.sort_values('TIEMPO_FALLA_CTE', ascending=False).head(30)

# %%
#Sustituír True y False por "Cliente" y "Totalplay"
#df_master.RESPONSABLE = df_master.RESPONSABLE.replace({True: "CLIENTE", False: "TOTALPLAY"})

# %%
df_master.loc[df_master['REF_NUM'].isin(df_conciliacion.REF_NUM)]
# Out:
#         REF_NUM                            NOMBRE ZES_PROACTIVO_REACTIVO  \
# 401     1834065         González Santiago Jorge                 REACTIVO
# 428     1834288            Sierra Duarte Rafael                 REACTIVO
# 476     1834512  Coutiño Arteaga Jesus Santiago                 REACTIVO
# 477     1834541          Puebla Santana Artemio                 REACTIVO
# 578     1835358       Lopez Alvarez Karla Itzel                 REACTIVO
# ...         ...                               ...                    ...
# 366164  2284927          Carmona Tovar Veronica                 REACTIVO
# 366174  2284933        Terrones Salazar Osvaldo                PROACTIVO
# 366406  2285420   Rosagel Mujica Carlos Enrique                 REACTIVO
# 366426  2285448   Rosagel Mujica Carlos Enrique                 REACTIVO
# 366430  2285458             SOTO JAIMEZ ABRAHAM                 REACTIVO
#
#                      SERVICIO_AFECTADO  \
# 401     SERVICIO DE DATOS ESTRATEGICOS
# ...

# %%
#df_master['RESPONSABLE'] = np.where(df_master.loc[df_master['REF_NUM'].isin(df_conciliacion.REF_NUM)]

# %%
df_master.loc[df_master['REF_NUM'].isin(df_conciliacion.REF_NUM)]
# Out:
#         REF_NUM                            NOMBRE ZES_PROACTIVO_REACTIVO  \
# 401     1834065         González Santiago Jorge                 REACTIVO
# 428     1834288            Sierra Duarte Rafael                 REACTIVO
# 476     1834512  Coutiño Arteaga Jesus Santiago                 REACTIVO
# 477     1834541          Puebla Santana Artemio                 REACTIVO
# 578     1835358       Lopez Alvarez Karla Itzel                 REACTIVO
# ...         ...                               ...                    ...
# 366164  2284927          Carmona Tovar Veronica                 REACTIVO
# 366174  2284933        Terrones Salazar Osvaldo                PROACTIVO
# 366406  2285420   Rosagel Mujica Carlos Enrique                 REACTIVO
# 366426  2285448   Rosagel Mujica Carlos Enrique                 REACTIVO
# 366430  2285458             SOTO JAIMEZ ABRAHAM                 REACTIVO
#
#                      SERVICIO_AFECTADO  \
# 401     SERVICIO DE DATOS ESTRATEGICOS
# ...

# %%
#df_01_06[df_01_06['REF_NUN']==1145368]

# %%
#Catálogo autogestinable de sitios críticos.
df_Cat_Criticos = gc.open('CAT_SITIOS_CRITICOS').worksheet("CAT_SITIOS_CRITICOS")
df_Cat_Criticos = df_Cat_Criticos.get_all_records(head=1)
df_Cat_Criticos = pd.DataFrame(df_Cat_Criticos)
df_master = pd.merge(df_master, df_Cat_Criticos.loc[:, ['CLIENTE_CMDB','SITIOS_CRITICOS']], how='left', on=['CLIENTE_CMDB'])
#df_master['SITIOS_CRITICOS'] = df_master.SITIOS_CRITICOS.fillna(0, inplace=True)
df_master = df_master.drop_duplicates()
df_Cat_Criticos.head()
# Out:
#              CUENTA                                       CLIENTE_CMDB  \
# 0   TFE-D-MPLS52675                                       10.206.114.6
# 1  TFE-OTR-OTR66441                                      10.253.115.65
# 2   TFE-D-MPLS62943                                       10.70.232.57
# 3   TFE-D-MPLS61164  5.37205.45_TFE-D-MPLS61164_OXXO_CEDIS_MTY_ESCO...
# 4     TFE-D-IS46293  5.37205_TFE-D-IS46293_CADENA_COMERCIAL_OXXO_SA...
#
#                  NOMBRE DEL SITO                  RAZON SOCIAL AGRUPACION  \
# 0  Oxxo Triara (Brazo Principal)         Cadena Comercial Oxxo
# 1                      Matamoros  TRISA COMERCIAL S.A. DE C.V.
# 2                      Cedis Gdl         Cadena Comercial Oxxo
# 3             Cedis Mty Escobedo         Cadena Comercial Oxxo
# 4            EDIFICIO TRIARA MTY         Cadena Comercial Oxxo
#
#    SITIOS_CRITICOS
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
#Catálogo autogestinable de sitios penalizables.
df_Cat_Penalizables = gc.open('CAT_SITIOS_CRITICOS').worksheet("CAT_CI_PENALIZABLES")
df_Cat_Penalizables = df_Cat_Penalizables.get_all_records(head=1)
df_Cat_Penalizables = pd.DataFrame(df_Cat_Penalizables)
df_master = pd.merge(df_master, df_Cat_Penalizables.loc[:, ['CLIENTE_CI','SITIOS_PENALIZABLES']], how='left', on=['CLIENTE_CI'])
#df_master['SITIOS_CRITICOS'] = df_master.SITIOS_CRITICOS.fillna(0, inplace=True)
df_master = df_master.drop_duplicates()
df_Cat_Penalizables.head()
# Out:
#                                           CLIENTE_CI  SITIOS_PENALIZABLES
# 0  ADMINISTRACION PORTUARIA INTEGRAL DE VERACRUZ ...                    1
# 1                 AEROPUERTOS Y SERVICIOS AUXILIARES                    1
# 2  Antes INSTITUTO NACIONAL PARA LA EVALUACIÓN DE...                    1
# 3          BENEMERITA UNIVERSIDAD AUTONOMA DE PUEBLA                    1
# 4        CENTRO DE CAPACITACION CINEMATOGRAFICA A.C.                    1

# %%
df_Cat_SLA = gc.open('CAT_SLA').worksheet("SLA")
df_Cat_SLA = df_Cat_SLA.get_all_records(head=1)
df_Cat_SLA = pd.DataFrame(df_Cat_SLA)
df_master = pd.merge(df_master, df_Cat_SLA.loc[:, ['CLIENTE_CI','SLA_CONTRATO_CI']], how='left', on=['CLIENTE_CI'])
#df_master.SLA_CONTRATO.fillna(99.4, inplace=True)

# %%
df_Cat_SLA_PUNTAS = gc.open('CAT_SLA').worksheet("PUNTAS")
df_Cat_SLA_PUNTAS = df_Cat_SLA_PUNTAS.get_all_records(head=1)
df_Cat_SLA_PUNTAS = pd.DataFrame(df_Cat_SLA_PUNTAS)
df_master = pd.merge(df_master, df_Cat_SLA_PUNTAS.loc[:, ['CLIENTE_CI','CLIENTE_CMDB','SLA_CONTRATO_PUNTA']], how='left', on=['CLIENTE_CI','CLIENTE_CMDB'])
df_master['SLA_CONTRATO'] = df_master['SLA_CONTRATO_PUNTA']
df_master['SLA_CONTRATO'] = np.where(df_master['SLA_CONTRATO'].isnull(), df_master['SLA_CONTRATO_CI'], df_master['SLA_CONTRATO_PUNTA'])
df_master.SLA_CONTRATO.fillna(99.4, inplace=True)

# %%
df_Cat_Segmentos = gc.open('Clientes por Segmento').worksheet("Segmentos")
df_Cat_Segmentos = df_Cat_Segmentos.get_all_records(head=1)
df_Cat_Segmentos = pd.DataFrame(df_Cat_Segmentos)

# %%
df_Cat_Segmentos.head()
# Out:
#                                                  RFC  \
# 0                           AB CAPITA SOCIEDAD CIVIL
# 1  ACTINVER CASA DE BOLSA SA DE CV GRUPO FINANCIE...
# 2  ADMINISTRACION DEL SISTEMA PORTUARIO NACIONAL ...
# 3  ADMINISTRACION DEL SISTEMA PORTUARIO NACIONAL ...
# 4  ADMINISTRACION DEL SISTEMA PORTUARIO NACIONAL ...
#
#                                      CLIENTE_CI  \
# 0                      AB CAPITA SOCIEDAD CIVIL
# 1                                      ACTINVER
# 2    ADMINISTRACION PORTUARIA INTEGRAL ENSENADA
# 3  ADMINISTRACION PORTUARIA INTEGRAL MANZANILLO
# 4    ADMINISTRACION PORTUARIA INTEGRAL VERACRUZ
#
#                                              Cliente  \
# 0                           AB CAPITA SOCIEDAD CIVIL
# 1  ACTINVER CASA DE BOLSA SA DE CV GRUPO FINANCIE...
# 2                  ADMINISTRACION PORTUARIA INTEGRAL
# 3                  ADMINISTRACION PORTUARIA INTEGRAL
# 4                  ADMINISTRACION PORTUARIA INTEGRAL
#
# ...

# %%
df_master = pd.merge(df_master, df_Cat_Segmentos.loc[:, ['CLIENTE_CI','UDN','REGION','SEGMENTO','PLAZA DE VENTA']], how='left', on=['CLIENTE_CI'])
df_master.SEGMENTO.fillna('-', inplace=True)
df_master['PLAZA DE VENTA'].fillna('-', inplace=True)
df_master.UDN.fillna('-', inplace=True)
df_master.REGION.fillna('-', inplace=True)

# %%
df_master.groupby(['CLIENTE_CI','CLIENTE_CMDB','SLA_CONTRATO'])['REF_NUM'].count().reset_index().to_csv('SLAs_diferentes.csv', index=False)

# %%
df_master.head()
# Out:
#    REF_NUM                                           NOMBRE  \
# 0  1455991  Integracion_SalesForce Integracion_SalesForce
# 1  1459812  Integracion_SalesForce Integracion_SalesForce
# 2  1499458  Integracion_SalesForce Integracion_SalesForce
# 3  1765007                            Garcia Bonilla Ivan
# 4  1791272                          González Barona David
#
#   ZES_PROACTIVO_REACTIVO SERVICIO_AFECTADO            FALLA  ESTATUS MOTIVO  \
# 0               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 1               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 2               REACTIVO        INCIDENTES       SALESFORCE  Cerrado    NaN
# 3              PROACTIVO               LAN         Internet  Cerrado    NaN
# 4               REACTIVO               LAN  Videovigilancia  Cerrado    NaN
#
#               GRUPO_ACTUAL PRIORIDAD        FECHA_INICIO  ... RESPONSABLE  \
# 0       NOC TPE SOPORTE N1   3-Media 2022-05-20 13:20:53  ...   TOTALPLAY
# ...

# %%
df_master.SITIOS_CRITICOS.fillna(0, inplace=True)
df_master.SITIOS_PENALIZABLES.fillna(0, inplace=True)
df_master.sort_values('SITIOS_CRITICOS', ascending=True)
df_master[df_master['SITIOS_PENALIZABLES'] == 1]
# Out:
#         REF_NUM                                             NOMBRE  \
# 588     1835358                        Lopez Alvarez Karla Itzel
# 589     1835413                          Aldaba Reyes Luis Angel
# 810     1836062                         Pérez Zamora Diana Itzel
# 1100    1836286                         Pérez Zamora Diana Itzel
# 1263    1836401                          Velazquez Rivera Javier
# ...         ...                                                ...
# 419493  2371220                           Carmona Tovar Veronica
# 419594  2372261                    GONZALEZ NUNEZ BRANDON DANIEL
# 419652  2372996                      Martinez Osorio Diego Armando
# 419741  2374634  Integracion SF Dashboard Web Integracion SF Da...
# 420114  2384700                          Aldaba Reyes Luis Angel
#
#        ZES_PROACTIVO_REACTIVO               SERVICIO_AFECTADO  \
# 588                  REACTIVO      SERVICIO DE DATOS GOBIERNO
# ...

# %%
df_tickets_padre_info = df_master.loc[df_master['REF_NUM'].isin(df_master.TICKET_PADRE)]
df_tickets_padre_info = df_tickets_padre_info[['REF_NUM','FECHA_INICIO','FECHA_HORA_NOTIF_SOLUCION','FECHA_CIERRE','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','DIAGNOSTICO','SOLUCION','RESUMEN','RESPONSABLE','AFECTACION_DE_SERVICIO','REGION_CIUDAD','AREA_RESOLUTORA']]
df_tickets_padre_info['MTTR'] = (df_tickets_padre_info.FECHA_HORA_NOTIF_SOLUCION - df_tickets_padre_info.FECHA_INICIO).dt.total_seconds()
df_tickets_padre_info.count()
# Out:
# REF_NUM                      17752
# FECHA_INICIO                 17752
# FECHA_HORA_NOTIF_SOLUCION    14013
# FECHA_CIERRE                 17752
# TIEMPO_FALLA_CTE             17752
# TIEMPO_FALLA_TPE             17752
# TIEMPO_FALLA_PROVEEDOR       17752
# TIEMPO_FALLA_TERCEROS        17752
# DIAGNOSTICO                  17752
# SOLUCION                     17752
# RESUMEN                      17752
# RESPONSABLE                  17752
# AFECTACION_DE_SERVICIO       17752
# REGION_CIUDAD                12900
# AREA_RESOLUTORA              13915
# MTTR                         14013
# dtype: int64

# %%
df_master.TICKET_PADRE.fillna('NULL', inplace=True)
df_tickets_padre = df_master.loc[df_master['TICKET_PADRE'] != 'NULL']
df_tickets_padre = df_tickets_padre[['TICKET_PADRE','REF_NUM','CLIENTE_CI','CLIENTE_CMDB','FECHA_INICIO','FECHA_CIERRE','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','DIAGNOSTICO','SOLUCION','RESPONSABLE','AFECTACION_DE_SERVICIO','SITIOS_CRITICOS','SITIOS_PENALIZABLES']]
df_tickets_padre = pd.merge(df_tickets_padre, df_tickets_padre_info.loc[:, ['REF_NUM','DIAGNOSTICO','SOLUCION','RESUMEN','REGION_CIUDAD','MTTR','AREA_RESOLUTORA','FECHA_INICIO','FECHA_CIERRE','FECHA_HORA_NOTIF_SOLUCION']], left_on='TICKET_PADRE', right_on='REF_NUM')
df_tickets_padre =  df_tickets_padre.drop_duplicates()

# %%
df_tickets_padre.count()
# Out:
# TICKET_PADRE                 40927
# REF_NUM_x                    40927
# CLIENTE_CI                   40927
# CLIENTE_CMDB                 40927
# FECHA_INICIO_x               40927
# FECHA_CIERRE_x               40927
# TIEMPO_FALLA_CTE             40927
# TIEMPO_FALLA_TPE             40927
# TIEMPO_FALLA_PROVEEDOR       40927
# TIEMPO_FALLA_TERCEROS        40927
# DIAGNOSTICO_x                40927
# SOLUCION_x                   40927
# RESPONSABLE                  40927
# AFECTACION_DE_SERVICIO       40927
# SITIOS_CRITICOS              40927
# SITIOS_PENALIZABLES          40927
# REF_NUM_y                    40927
# DIAGNOSTICO_y                40927
# SOLUCION_y                   40927
# RESUMEN                      40927
# REGION_CIUDAD                30117
# MTTR                         34131
# AREA_RESOLUTORA              31908
# FECHA_INICIO_y               40927
# FECHA_CIERRE_y               40927
# FECHA_HORA_NOTIF_SOLUCION    34131
# dtype: int64

# %%
#Identificar y separar Clientes Null, se acota a solo 2021 para agilizar el cálculo
df_null = df_master[df_master['CLIENTE_CI'] == 'NULL']
df_sitios_null = df_master[(df_master['CLIENTE_CMDB'] == 'NULL') | (df_master['CLIENTE_CMDB'] == 'PUNTA SIN CLIENTE') | (df_master['CLIENTE_CMDB'] == 'PUNTAS SIN CLIENTE')]
df_master.GRUPO_ACTUAL.fillna('NULL', inplace=True)
df_pretickets = df_master.loc[df_master['GRUPO_ACTUAL'].str.contains(r'(?i)\w*PRE-TICKET\w*')]
df_master = df_master[df_master['CLIENTE_CI'] != 'NULL']
df_master = df_master.loc[df_master['GRUPO_ACTUAL'].str.contains(r'(?i)\w*PRE-TICKET\w*') == False]
df_master = df_master[df_master['ESTATUS'] == 'Cerrado'] # Se omiten los Estatus Cancelados.
df_master = df_master.loc[~df_master['REF_NUM'].isin(df_master.TICKET_PADRE)]

# %%
df_pretickets.REF_NUM.count() + df_null.REF_NUM.count() + df_master.REF_NUM.count()
# Out:
# 416253

# %%
df_null.to_csv("CI_NULL.csv")

# %%
#df_master sin CLIENTES NULL
df_master.REF_NUM.count() + df_null.REF_NUM.count()
# Out:
# 339129

# %%
#Selección y fltros
#df7[df7['CLIENTE_CMDB'].str.contains(r'^(?=.*485754)')]
#df7['CLIENTE_CMDB'].str.contains('485754', regex=False)
#filter = df_master[df_master['CLIENTE_CMDB'].str.contains('485754') & df_master['CLIENTE_CI'].str.contains(r'^(?=.*)')]
#df7.set_index('CLIENTE_CMDB').filter(like='485754', axis=0)
#filter[['CLIENTE_CI','CLIENTE_CMDB']].to_csv('485754')
#filter.head()

# %%
df_master.groupby('AFECTACION_DE_SERVICIO').count()
# Out:
#                         REF_NUM  NOMBRE  ZES_PROACTIVO_REACTIVO  \
# AFECTACION_DE_SERVICIO
# NO                          631     631                     621
# SI                       130461  130461                  130217
#
#                         SERVICIO_AFECTADO   FALLA  ESTATUS  MOTIVO  \
# AFECTACION_DE_SERVICIO
# NO                                    418     631      631     157
# SI                                 114579  130461   130461    4277
#
#                         GRUPO_ACTUAL  PRIORIDAD  FECHA_INICIO  ...  \
# AFECTACION_DE_SERVICIO                                         ...
# NO                               631        631           631  ...
# SI                            130461     130461        130461  ...
#
#                         RESPONSABLE  SITIOS_CRITICOS  SITIOS_PENALIZABLES  \
# AFECTACION_DE_SERVICIO
# NO                              631              631                  631
# ...

# %%
#df_master[df_master['CLIENTE_CMDB']=='SUC-0146-TFE-D-IS37006-BANAMEX-CF-MATAMOROSTAMPS']

# %%
#Filtrar incidentes del Cliente y de Totalplay en un DF
df_Cliente = df_master[(df_master['RESPONSABLE'] =='CLIENTE')]
df_Totalplay = df_master[(df_master['RESPONSABLE'] =='TOTALPLAY')]
df_Cliente = df_Cliente.drop_duplicates()
df_Totalplay = df_Totalplay.drop_duplicates()

# %%
df_Totalplay[df_Totalplay['REF_NUM']==1111459]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, NOMBRE, ZES_PROACTIVO_REACTIVO, SERVICIO_AFECTADO, FALLA, ESTATUS, MOTIVO, GRUPO_ACTUAL, PRIORIDAD, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, DURACION, DIAGNOSTICO, SOLUCION, AREA_RESOLUTORA, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, AFECTACION_DE_SERVICIO, RESUMEN, DESCRIPCION, TICKET_SISTEMA_EXTERNO, REGION_CIUDAD, TICKET_PADRE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, CLIENTE_CI, CLIENTE_CMDB, IP_CMDB, TIEMPO_ACTIVIDAD, DIAGNOSTICO_INCIAL, FECHA_HORA_ACTIVIDADES_REALIZADAS, TIPO_DE_RED, PUNTA_CI, MARCA, MODELO, sitio_correcto_cat, cliente_correcto_cat, AÑO, MES, SEMANA, DIA, HORA, RESPONSABLE, SITIOS_CRITICOS, SITIOS_PENALIZABLES, SLA_CONTRATO_CI, SLA_CONTRATO_PUNTA, SLA_CONTRATO, UDN, REGION, SEGMENTO, PLAZA DE VENTA]
# Index: []
#
# [0 rows x 53 columns]

# %%
df_reincidencias_TP = df_master.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES','RESPONSABLE','SITIOS_CRITICOS'])['REF_NUM'].count().reset_index()
df_reincidencias_TP = df_reincidencias_TP.sort_values('REF_NUM', ascending=False)
df_reincidencias_TP = df_reincidencias_TP[df_reincidencias_TP['CLIENTE_CMDB'] != 'PUNTA SIN CLIENTE']
df_reincidencias_TP.head()
# Out:
#       CLIENTE_CI CLIENTE_CMDB   AÑO  MES RESPONSABLE  SITIOS_CRITICOS  REF_NUM
# 36696    ELEKTRA      ELEKTRA  2023   12   TOTALPLAY              0.0      217
# 36694    ELEKTRA      ELEKTRA  2023   11   TOTALPLAY              0.0      192
# 36682    ELEKTRA      ELEKTRA  2023    5   TOTALPLAY              0.0      169
# 36690    ELEKTRA      ELEKTRA  2023    9   TOTALPLAY              0.0      167
# 36692    ELEKTRA      ELEKTRA  2023   10   TOTALPLAY              0.0      163

# %%
#df_Totalplay[df_Totalplay['CLIENTE_CMDB']=='SUC-0146-TFE-D-IS37006-BANAMEX-CF-MATAMOROSTAMPS']

# %%
df_Cliente.REF_NUM.count()
# Out:
# 33879

# %%
df_Totalplay.REF_NUM.count()
# Out:
# 87051

# %%
#Seleccionar incidentes de client solo de 2021.
#cat_fallas_cliente_2021 = df_Cliente[(df_Cliente['FECHA_INICIO'] >= '2021-01-01')]

# %%
#Obtner categorías de fallas de cliente del 2021.
#cat_fallas_cliente_2021.groupby(['DIAGNOSTICO','SOLUCION','AREA_RESOLUTORA'])['REF_NUM'].count().reset_index()

# %%
#cat_fallas_cliente_2021 = cat_fallas_cliente_2021.sort_values('REF_NUM', ascending=False)

# %%
#Regla para obtener los horas correspondietes al mes.
df_horas_mes = df_Totalplay.groupby(['AÑO','MES'])['DIA'].agg('max').reset_index()
df_horas_mes['DIA'] = np.where(df_horas_mes['DIA'] <28, 30, df_horas_mes['DIA'])
df_horas_mes['HORAS_MES'] = pd.to_timedelta(df_horas_mes.DIA * 86400000000000)
df_horas_mes['HORAS_MES_NUM'] = df_horas_mes['HORAS_MES'].dt.total_seconds() / (60 * 60)

# %%
#cat_fallas_cliente_2021.to_csv('Cat_Fallas_Cliente_2021.csv', encoding='latin-1')

# %%
#df_Totalplay["MTTR"] = df_Totalplay.TIEMPO_FALLA_CTE + df_Totalplay.TIEMPO_FALLA_TPE + df_Totalplay.TIEMPO_FALLA_PROVEEDOR + df_Totalplay.TIEMPO_FALLA_TERCEROS)

# %%
df_Totalplay.TIEMPO_FALLA_TPE + df_Totalplay.TIEMPO_FALLA_PROVEEDOR + df_Totalplay.TIEMPO_FALLA_TERCEROS
# Out:
# 0         5 days 05:05:14
# 1         0 days 02:30:24
# 2        34 days 22:59:59
# 3        35 days 01:35:01
# 4        45 days 19:23:59
#                ...
# 420138    0 days 00:00:00
# 420142    0 days 00:00:00
# 420149    0 days 00:00:00
# 420155    0 days 00:00:00
# 420158    0 days 00:00:00
# Length: 87051, dtype: timedelta64[ns]

# %%
#Regla de Negocios Para tiempos TP, sumar tiempos atribuíbles a Totalplay
#df_master["TOTAL_TIME"] = df_master.iloc[:,[21,28,29]].sum(axis=1)
df_Totalplay["TOTAL_TIME"] = np.where(df_Totalplay['AFECTACION_DE_SERVICIO']=='SI', df_Totalplay.TIEMPO_FALLA_TPE + df_Totalplay.TIEMPO_FALLA_PROVEEDOR + df_Totalplay.TIEMPO_FALLA_TERCEROS, pd.to_timedelta(0, unit='s'))
df_Totalplay["TOTAL_TIME"] = pd.to_timedelta(df_Totalplay['TOTAL_TIME'])

# %%
df_Totalplay['TOTAL_TIME'].head()
# Out:
# 0    5 days 05:05:14
# 1    0 days 02:30:24
# 2   34 days 22:59:59
# 3   35 days 01:35:01
# 4   45 days 19:23:59
# Name: TOTAL_TIME, dtype: timedelta64[ns]

# %%
#df_Totalplay["MTBF"] = np.where(((df_Totalplay['TOTAL_TIME'] < pd.to_timedelta("24:00:00")) & (df_Totalplay['TOTAL_TIME'] > pd.to_timedelta("0:00:00"))),  pd.to_timedelta("24:00:00") - df_Totalplay['TOTAL_TIME'], 0)

# %%
#df_Totalplay["TOTAL_TIME"].dt.total_seconds() / (60 * 60)
#df_Totalplay.sort_values('MTBF', ascending=True).head()

# %%
df_mttr_mtbf = df_master[['REF_NUM','CLIENTE_CI','CLIENTE_CMDB','AÑO','MES','SEMANA','REGION_CIUDAD', 'RESPONSABLE','GRUPO_ACTUAL']]
df_mttr_mtbf['TOTAL_TIME'] = (df_master.TIEMPO_FALLA_CTE + df_master.TIEMPO_FALLA_TPE + df_master.TIEMPO_FALLA_PROVEEDOR + df_master.TIEMPO_FALLA_TERCEROS).dt.total_seconds()
df_mttr_mtbf['MTTR_TP'] = (df_master.TIEMPO_FALLA_TPE + df_master.TIEMPO_FALLA_PROVEEDOR + df_master.TIEMPO_FALLA_TERCEROS).dt.total_seconds()
df_mttr_mtbf['MTTR_CTE'] = df_master.TIEMPO_FALLA_CTE.dt.total_seconds()
#df_mttr_mtbf['AÑO'] = 2021
df_mttr_mtbf = (pd.merge(df_mttr_mtbf, df_horas_mes.loc[:, ['AÑO','MES','HORAS_MES']], how='left', on=['AÑO','MES']))
df_mttr_mtbf['HORAS_MES'] = df_mttr_mtbf['HORAS_MES'].dt.total_seconds()
df_mttr_mtbf['MTBF'] = np.where(df_mttr_mtbf['HORAS_MES'] >= df_mttr_mtbf['TOTAL_TIME'], df_mttr_mtbf['HORAS_MES'] - df_mttr_mtbf['TOTAL_TIME'],0)
df_mttr_mtbf['MTTR_CARE'] = np.where(df_mttr_mtbf['GRUPO_ACTUAL'].str.contains(r'(?i)\w*CARE\w*'), df_mttr_mtbf['MTTR_TP'] ,0)
df_mttr_mtbf['MTTR_OTROS'] = np.where(~df_mttr_mtbf['GRUPO_ACTUAL'].str.contains(r'(?i)\w*CARE\w*'), df_mttr_mtbf['MTTR_TP'] ,0)


df_mttr_mtbf = df_mttr_mtbf.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES', 'SEMANA']).agg(
    TOTAL_TIME = pd.NamedAgg(column='TOTAL_TIME', aggfunc=np.mean),
    MTTR_TP = pd.NamedAgg(column='MTTR_TP', aggfunc=np.mean),
    MTTR_CTE = pd.NamedAgg(column='MTTR_CTE', aggfunc=np.mean),
    MTBF = pd.NamedAgg(column='MTBF', aggfunc=np.mean),
    TOTAL_TICKETs = pd.NamedAgg(column='REF_NUM', aggfunc=pd.Series.nunique),
    REGION = pd.NamedAgg(column="REGION_CIUDAD", aggfunc=lambda x: list(set(x))),
    TICKETs = pd.NamedAgg(column="REF_NUM", aggfunc=lambda x: list(set(x))),
    MTTR_CARE = pd.NamedAgg(column='MTTR_CARE', aggfunc=np.mean),
    MTTR_OTROS =pd.NamedAgg(column='MTTR_OTROS', aggfunc=np.mean)).reset_index()
df_mttr_mtbf.head()
# Out:
# <ipython-input-119-5c5f883c531b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mttr_mtbf['TOTAL_TIME'] = (df_master.TIEMPO_FALLA_CTE + df_master.TIEMPO_FALLA_TPE + df_master.TIEMPO_FALLA_PROVEEDOR + df_master.TIEMPO_FALLA_TERCEROS).dt.total_seconds()
# <ipython-input-119-5c5f883c531b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mttr_mtbf['MTTR_TP'] = (df_master.TIEMPO_FALLA_TPE + df_master.TIEMPO_FALLA_PROVEEDOR + df_master.TIEMPO_FALLA_TERCEROS).dt.total_seconds()
# ...

# %%
df_mttr_mtbf.head()
# Out:
#            CLIENTE_CI                                CLIENTE_CMDB   AÑO  MES  \
# 0                       TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023   12
# 1                       TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2024    2
# 2                      TFE-VD-OTR82014 K790-I Paseo Acoxpa_Kiosco  2023   12
# 3                      TFE-VD-OTR82014 K790-I Paseo Acoxpa_Kiosco  2024    4
# 4   Comentarios: test                           Comentarios: test  2024    5
#
#    SEMANA  TOTAL_TIME  MTTR_TP  MTTR_CTE       MTBF  TOTAL_TICKETs  \
# 0      50      2997.0   2997.0       0.0  2675403.0              1
# 1       6      9363.0   2166.0    7197.0  2496237.0              1
# 2      50     19475.0    139.0   19336.0  2658925.0              1
# 3      14     11857.0     82.0   11775.0  2580143.0              1
# 4      19     14445.0  14445.0       0.0  2577555.0              1
#
#                           REGION    TICKETs  MTTR_CARE  MTTR_OTROS
# ...

# %%
#df_Totalplay.loc[(df_Totalplay["CLIENTE_CMDB"] =="UNIDAD DE SERVICIOS EDUCATIVOS_200261683") & (df_Totalplay["FECHA_CIERRE"] >= '2020-12-01') & (df_Totalplay["FECHA_CIERRE"] <= '2020-12-31')].count()

# %%
#Regla de Negocios Para tiempos Cliente, sumar tiempos atribuíbles al Cliente
df_Cliente["TOTAL_TIME"] = df_Cliente.TIEMPO_FALLA_CTE + df_Cliente.TIEMPO_FALLA_TPE + df_Cliente.TIEMPO_FALLA_PROVEEDOR + df_Cliente.TIEMPO_FALLA_TERCEROS
df_Cliente["TOTAL_TIME"] = pd.to_timedelta(df_Cliente['TOTAL_TIME'])
df_Cliente.head()
# Out:
#     REF_NUM                                           NOMBRE  \
# 5   1799358                        Brito Arce Jose Augusto
# 15  1648550  Integracion_SalesForce Integracion_SalesForce
# 20  1689841                       Frias Sanchez Eric Oscar
# 28  1834544                        Brito Arce Jose Augusto
# 46  1776686                 Aguilar Gutierrez Edgar Adrian
#
#    ZES_PROACTIVO_REACTIVO           SERVICIO_AFECTADO  \
# 5                REACTIVO  SERVICIO DE DATOS GOBIERNO
# 15               REACTIVO               AYUDA TÉCNICA
# 20              PROACTIVO                         LAN
# 28               REACTIVO  SERVICIO DE DATOS GOBIERNO
# 46               REACTIVO                         VOZ
#
#                           FALLA  ESTATUS MOTIVO             GRUPO_ACTUAL  \
# 5       INTERNET.SIN NAVEGACIÓN  Cerrado    NaN              IMPLANT SAT
# 15      ALORES AGREGADOS.CORREO  Cerrado    NaN       NOC TPE SOPORTE N1
# ...

# %%
df_Totalplay[(df_Totalplay['CLIENTE_CMDB']=="TFE-D-IS58356_EDIT_TRILLAS_CORPORATIVO_NUEVA") & (df_Totalplay['MES']==8)]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, NOMBRE, ZES_PROACTIVO_REACTIVO, SERVICIO_AFECTADO, FALLA, ESTATUS, MOTIVO, GRUPO_ACTUAL, PRIORIDAD, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, DURACION, DIAGNOSTICO, SOLUCION, AREA_RESOLUTORA, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, AFECTACION_DE_SERVICIO, RESUMEN, DESCRIPCION, TICKET_SISTEMA_EXTERNO, REGION_CIUDAD, TICKET_PADRE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, CLIENTE_CI, CLIENTE_CMDB, IP_CMDB, TIEMPO_ACTIVIDAD, DIAGNOSTICO_INCIAL, FECHA_HORA_ACTIVIDADES_REALIZADAS, TIPO_DE_RED, PUNTA_CI, MARCA, MODELO, sitio_correcto_cat, cliente_correcto_cat, AÑO, MES, SEMANA, DIA, HORA, RESPONSABLE, SITIOS_CRITICOS, SITIOS_PENALIZABLES, SLA_CONTRATO_CI, SLA_CONTRATO_PUNTA, SLA_CONTRATO, UDN, REGION, SEGMENTO, PLAZA DE VENTA, TOTAL_TIME]
# Index: []
#
# [0 rows x 54 columns]

# %%
df_Totalplay.columns
# Out:
# Index(['REF_NUM', 'NOMBRE', 'ZES_PROACTIVO_REACTIVO', 'SERVICIO_AFECTADO',
#        'FALLA', 'ESTATUS', 'MOTIVO', 'GRUPO_ACTUAL', 'PRIORIDAD',
#        'FECHA_INICIO', 'FECHA_HORA_NOTIF_SOLUCION', 'FECHA_CIERRE', 'DURACION',
#        'DIAGNOSTICO', 'SOLUCION', 'AREA_RESOLUTORA', 'TIEMPO_FALLA_CTE',
#        'TIEMPO_FALLA_TPE', 'AFECTACION_DE_SERVICIO', 'RESUMEN', 'DESCRIPCION',
#        'TICKET_SISTEMA_EXTERNO', 'REGION_CIUDAD', 'TICKET_PADRE',
#        'TIEMPO_FALLA_PROVEEDOR', 'TIEMPO_FALLA_TERCEROS', 'CLIENTE_CI',
#        'CLIENTE_CMDB', 'IP_CMDB', 'TIEMPO_ACTIVIDAD', 'DIAGNOSTICO_INCIAL',
#        'FECHA_HORA_ACTIVIDADES_REALIZADAS', 'TIPO_DE_RED', 'PUNTA_CI', 'MARCA',
#        'MODELO', 'sitio_correcto_cat', 'cliente_correcto_cat', 'AÑO', 'MES',
#        'SEMANA', 'DIA', 'HORA', 'RESPONSABLE', 'SITIOS_CRITICOS',
#        'SITIOS_PENALIZABLES', 'SLA_CONTRATO_CI', 'SLA_CONTRATO_PUNTA',
#        'SLA_CONTRATO', 'UDN', 'REGION', 'SEGMENTO', 'PLAZA DE VENTA',
# ...

# %%
# Regla de negocios para obtener inconsistencias Tiempos en cero y negativos
df_tiempos_cero = df_Totalplay[(df_Totalplay['TOTAL_TIME'] <= pd.Timedelta(0,'m')) & (df_Totalplay['AFECTACION_DE_SERVICIO'] == 'SI')]
df_tiempos_cero = df_tiempos_cero[['REF_NUM','CLIENTE_CI','CLIENTE_CMDB','DIAGNOSTICO','SOLUCION','RESUMEN','FECHA_INICIO','FECHA_HORA_NOTIF_SOLUCION','FECHA_CIERRE','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','TOTAL_TIME','AFECTACION_DE_SERVICIO','RESPONSABLE','AÑO','MES']]
df_tiempos_cero =  df_tiempos_cero.sort_values('TOTAL_TIME', ascending=True)

# %%
df_tiempos_cero.sort_values('TOTAL_TIME', ascending=True)
# Out:
#         REF_NUM                               CLIENTE_CI  \
# 4099    1839161  INSTITUTO FEDERAL DE TELECOMUNICACIONES
# 22585   1859087            GOBIERNO DEL ESTADO DE MEXICO
# 29138   1872114                              SRE REMOTAS
# 43171   1885500  INSTITUTO FEDERAL DE TELECOMUNICACIONES
# 55478   1898543                      PETROLEOS MEXICANOS
# ...         ...                                      ...
# 420142  2385598    SOLUCIONES EN TECNOLOGIA Y DESARROLLO
# 420149  2385855                     JOSUE OROZCO SANCHEZ
# 420101  2384590                     MUNICIPIO DE APODACA
# 417978  2378723                              BANAMEX ATM
# 420158  2386192               MOVIMIENTO CIUDADANO SDWAN
#
#                                              CLIENTE_CMDB  \
# 4099                          TFE-D-ID46520_Sede/Internet
# 22585   TFE-D-IS78494_CSP9223939-CENTRO CULTURAL EDOME...
# 29138   200553688_COMISIONES INTERNACIONALES DE LIMITE...
# ...

# %%
df_tiempos_cero[df_tiempos_cero['REF_NUM']==1164674]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, CLIENTE_CI, CLIENTE_CMDB, DIAGNOSTICO, SOLUCION, RESUMEN, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, TOTAL_TIME, AFECTACION_DE_SERVICIO, RESPONSABLE, AÑO, MES]
# Index: []

# %%
#Regla de negocios para descartar tiempos en cero y negativos
df_Totalplay = df_Totalplay[df_Totalplay['TOTAL_TIME'] >= pd.Timedelta(0, "m")]

# %%
df_Totalplay.groupby('AFECTACION_DE_SERVICIO')['REF_NUM'].count()
# Out:
# AFECTACION_DE_SERVICIO
# NO      248
# SI    86803
# Name: REF_NUM, dtype: int64

# %%
print(pd.Timedelta(0, "s"))
# Out:
# 0 days 00:00:00

# %%
#df_tiempos_cero.to_csv('TIEMPOS_NEGATIVOS.CSV')

# %%
df_horas_mes.head(50)
# Out:
#      AÑO  MES  DIA HORAS_MES  HORAS_MES_NUM
# 0   2023    5   31   31 days          744.0
# 1   2023    6   30   30 days          720.0
# 2   2023    7   31   31 days          744.0
# 3   2023    8   31   31 days          744.0
# 4   2023    9   30   30 days          720.0
# 5   2023   10   31   31 days          744.0
# 6   2023   11   30   30 days          720.0
# 7   2023   12   31   31 days          744.0
# 8   2024    1   31   31 days          744.0
# 9   2024    2   29   29 days          696.0
# 10  2024    3   31   31 days          744.0
# 11  2024    4   30   30 days          720.0
# 12  2024    5   30   30 days          720.0

# %%
#Cáluclo de Sitios Fuera de SLA, aplicar disp con números completos'
#df_TP_Sitios_Disp = df_Totalplay.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES']).agg({'TOTAL_TIME':'sum', 'TIEMPO_FALLA_PROVEEDOR': 'sum', 'SITIOS_CRITICOS': 'mean', 'SLA_CONTRATO': 'min', 'REF_NUM': lambda x: list(x)}).reset_index()
df_Totalplay = df_Totalplay.drop_duplicates()
df_TP_Sitios_Disp = df_Totalplay.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES']).agg(
    TOTAL_TIME = pd.NamedAgg(column='TOTAL_TIME', aggfunc=np.sum),
    TIEMPO_FALLA_PROVEEDOR = pd.NamedAgg(column='TIEMPO_FALLA_PROVEEDOR', aggfunc=np.sum),
    SITIOS_CRITICOS = pd.NamedAgg(column='SITIOS_CRITICOS', aggfunc=np.mean),
    SITIOS_PENALIZABLES = pd.NamedAgg(column='SITIOS_PENALIZABLES', aggfunc=np.mean),
    SLA_CONTRATO = pd.NamedAgg(column='SLA_CONTRATO', aggfunc=np.min),
    TOTAL_TICKETs = pd.NamedAgg(column='REF_NUM', aggfunc=pd.Series.nunique),
    TICKETs = pd.NamedAgg(column="REF_NUM", aggfunc=lambda x: list(set(x)))).reset_index()

df_TP_Sitios_Disp = pd.merge(df_TP_Sitios_Disp, df_horas_mes.loc[:, ['AÑO','MES','HORAS_MES']], how='left', on=['AÑO','MES'])
df_TP_Sitios_Disp.sort_values('TOTAL_TIME', ascending=False).head()
df_TP_Sitios_Disp['DISPONIBILIDAD'] = np.where(df_TP_Sitios_Disp['HORAS_MES'] > df_TP_Sitios_Disp['TOTAL_TIME'], (100-((df_TP_Sitios_Disp.TOTAL_TIME / df_TP_Sitios_Disp.HORAS_MES)*100)), 0)
df_TP_Sitios_Disp['DISPONIBILIDAD'] = df_TP_Sitios_Disp['DISPONIBILIDAD'].round(2)
df_TP_Sitios_Disp = df_TP_Sitios_Disp.sort_values(['MES','DISPONIBILIDAD'], ascending=[False,True])
df_TP_Sitios_Disp['SLA'] = np.where(df_TP_Sitios_Disp['DISPONIBILIDAD'] >= df_TP_Sitios_Disp['SLA_CONTRATO'] , 'DENTRO', 'FUERA')
df_TP_Sitios_Disp['SLA_PROVEEDOR'] = np.where(df_TP_Sitios_Disp['TIEMPO_FALLA_PROVEEDOR'] <=  pd.Timedelta(4, "h"), 'DENTRO', 'FUERA')
df_TP_Sitios_Disp['TOTAL_TIME'] = (df_TP_Sitios_Disp["TOTAL_TIME"].dt.total_seconds().round(0))
df_TP_Sitios_Disp['TIEMPO_FALLA_PROVEEDOR'] = (df_TP_Sitios_Disp["TIEMPO_FALLA_PROVEEDOR"].dt.total_seconds().round(0))

# %%
df_Totalplay = df_Totalplay.drop_duplicates()
df_sitios_fuera_sem = df_Totalplay[df_Totalplay['MES']>=10]
#df_sitios_fuera_sem['DIAGNOSTICO'] = df_sitios_fuera_sem['DIAGNOSTICO'].strip()
df_sitios_fuera_sem = df_Totalplay.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES']).agg(
    TOTAL_TIME = pd.NamedAgg(column='TOTAL_TIME', aggfunc=np.sum),
    TIEMPO_FALLA_PROVEEDOR = pd.NamedAgg(column='TIEMPO_FALLA_PROVEEDOR', aggfunc=np.sum),
    SITIOS_CRITICOS = pd.NamedAgg(column='SITIOS_CRITICOS', aggfunc=np.mean),
    SITIOS_PENALIZABLES = pd.NamedAgg(column='SITIOS_PENALIZABLES', aggfunc=np.mean),
    SLA_CONTRATO = pd.NamedAgg(column='SLA_CONTRATO', aggfunc=np.min),
    TOTAL_TICKETs = pd.NamedAgg(column='REF_NUM', aggfunc=pd.Series.nunique),
    TICKETs = pd.NamedAgg(column="REF_NUM", aggfunc=lambda x: list(set(x))),
    FECHA_CIERRE = pd.NamedAgg(column='FECHA_CIERRE', aggfunc=np.min),
    DIAGNOSTICO = pd.NamedAgg(column="DIAGNOSTICO", aggfunc=lambda x: list(set(x))),
    SOLUCION = pd.NamedAgg(column="SOLUCION", aggfunc=lambda x: list(set(x))),
    AREA_RESOLUTORA = pd.NamedAgg(column="AREA_RESOLUTORA", aggfunc=lambda x: list(set(x))),
    REGION_CIUDAD = pd.NamedAgg(column="REGION_CIUDAD", aggfunc=lambda x: list(set(x)))).reset_index()

df_sitios_fuera_sem = pd.merge(df_sitios_fuera_sem, df_horas_mes.loc[:, ['AÑO','MES','HORAS_MES']], how='left', on=['AÑO','MES'])
df_sitios_fuera_sem.sort_values('TOTAL_TIME', ascending=False).head()
df_sitios_fuera_sem['DISPONIBILIDAD'] = np.where(df_sitios_fuera_sem['HORAS_MES'] > df_sitios_fuera_sem['TOTAL_TIME'], (100-((df_sitios_fuera_sem.TOTAL_TIME / df_sitios_fuera_sem.HORAS_MES)*100)), 0)
df_sitios_fuera_sem['DISPONIBILIDAD'] = df_sitios_fuera_sem['DISPONIBILIDAD'].round(2)
df_sitios_fuera_sem = df_sitios_fuera_sem.sort_values(['MES','DISPONIBILIDAD'], ascending=[False,True])
df_sitios_fuera_sem['SLA'] = np.where(df_sitios_fuera_sem['DISPONIBILIDAD'] >= df_sitios_fuera_sem['SLA_CONTRATO'] , 'DENTRO', 'FUERA')
df_sitios_fuera_sem['SLA_PROVEEDOR'] = np.where(df_sitios_fuera_sem['TIEMPO_FALLA_PROVEEDOR'] <=  pd.Timedelta(4, "h"), 'DENTRO', 'FUERA')
df_sitios_fuera_sem['TOTAL_TIME'] = (df_sitios_fuera_sem["TOTAL_TIME"].dt.total_seconds().round(0))
df_sitios_fuera_sem['TIEMPO_FALLA_PROVEEDOR'] = (df_sitios_fuera_sem["TIEMPO_FALLA_PROVEEDOR"].dt.total_seconds().round(0))

# %%
df_sitios_fuera_sem.AREA_RESOLUTORA.replace('NULL', 'nan', inplace=True)
df_sitios_fuera_sem = df_sitios_fuera_sem[df_sitios_fuera_sem['SLA']=='FUERA']
df_sitios_fuera_sem.head()
# Out:
#                          CLIENTE_CI  \
# 1550  AT&T COMUNICACIONES DIGITALES
# 1958     AUTO PARTES Y MAS SA DE CV
# 2020     AUTO PARTES Y MAS SA DE CV
# 2022     AUTO PARTES Y MAS SA DE CV
# 2510                    BANAMEX ATM
#
#                                            CLIENTE_CMDB   AÑO  MES  \
# 1550  GS-D-VPN50845_550226_Pabellon_Acapulco_AT&T Ti...  2023   12
# 1958                        200193098_AUTO PARTES Y MAS  2023   12
# 2020                         AUTO PARTES Y MAS SA DE CV  2023   12
# 2022                        AUTO PARTES Y MAS, SA DE CV  2023   12
# 2510  0200472005_D-MPLS82707_BANAMEX_ID_1833_CONVENC...  2023   12
#
#       TOTAL_TIME  TIEMPO_FALLA_PROVEEDOR  SITIOS_CRITICOS  \
# 1550   3020399.0                     0.0              0.0
# 1958   3020399.0                     0.0              0.0
# 2020   3041166.0                     0.0              0.0
# 2022   3020399.0                     0.0              0.0
# ...

# %%
df_TP_Sitios_Disp.head()
# Out:
#                          CLIENTE_CI  \
# 1550  AT&T COMUNICACIONES DIGITALES
# 1958     AUTO PARTES Y MAS SA DE CV
# 2020     AUTO PARTES Y MAS SA DE CV
# 2022     AUTO PARTES Y MAS SA DE CV
# 2510                    BANAMEX ATM
#
#                                            CLIENTE_CMDB   AÑO  MES  \
# 1550  GS-D-VPN50845_550226_Pabellon_Acapulco_AT&T Ti...  2023   12
# 1958                        200193098_AUTO PARTES Y MAS  2023   12
# 2020                         AUTO PARTES Y MAS SA DE CV  2023   12
# 2022                        AUTO PARTES Y MAS, SA DE CV  2023   12
# 2510  0200472005_D-MPLS82707_BANAMEX_ID_1833_CONVENC...  2023   12
#
#       TOTAL_TIME  TIEMPO_FALLA_PROVEEDOR  SITIOS_CRITICOS  \
# 1550   3020399.0                     0.0              0.0
# 1958   3020399.0                     0.0              0.0
# 2020   3041166.0                     0.0              0.0
# 2022   3020399.0                     0.0              0.0
# ...

# %%
df_Frec_Fuera_SLA = df_TP_Sitios_Disp[(df_TP_Sitios_Disp['SLA']=='FUERA') & (df_TP_Sitios_Disp['MES']>= 6)].groupby(['CLIENTE_CI','CLIENTE_CMDB'])['MES'].count().reset_index(name='FREC_FUERA_SLA')
df_Frec_Fuera_SLA = df_Frec_Fuera_SLA.sort_values('FREC_FUERA_SLA', ascending = False)

# %%
df_Frec_Fuera_SLA.head()
# Out:
#                 CLIENTE_CI                             CLIENTE_CMDB  \
# 7122        McDONALDS CCTV  TFE-VD-OTR44462 368 La Isla Cancún_CCTV
# 10648  TIENDAS SUPERPRECIO                      TIENDAS SUPERPRECIO
# 8887    RED DORSAL JALISCO           PM_081 San Sebastian del Oeste
# 7840           PCCW GLOBAL                          SENP-D-L2L99467
# 8881    RED DORSAL JALISCO           PM_065\tPRESIDENCIA DE PIHUAMO
#
#        FREC_FUERA_SLA
# 7122                7
# 10648               7
# 8887                7
# 7840                7
# 8881                7

# %%
df_TP_Sitios_Disp = pd.merge(df_TP_Sitios_Disp, df_Frec_Fuera_SLA.loc[:, ['CLIENTE_CI','CLIENTE_CMDB','FREC_FUERA_SLA']], how='left', on=['CLIENTE_CI','CLIENTE_CMDB'])
#df_TP_Sitios_Disp['FREC_FUERA_SLA'] = df_TP_Sitios_Disp['FREC_FUERA_SLA'].fillna(0, inplace=True)

# %%
df_TP_Sitios_Disp.sort_values('FREC_FUERA_SLA', ascending=False).head()
# Out:
#                 CLIENTE_CI                            CLIENTE_CMDB   AÑO  MES  \
# 33724   RED DORSAL JALISCO          PM_081 San Sebastian del Oeste  2023    6
# 46681          PCCW GLOBAL                         SENP-D-L2L99467  2024    4
# 20863  PETROLEOS MEXICANOS  SENP-D-L2L87090_SIT MINATITLAN_B_PEMEX  2023    8
# 47020  TIENDAS SUPERPRECIO                     TIENDAS SUPERPRECIO  2024    4
# 46902   RED DORSAL JALISCO          PM_065\tPRESIDENCIA DE PIHUAMO  2024    4
#
#        TOTAL_TIME  TIEMPO_FALLA_PROVEEDOR  SITIOS_CRITICOS  \
# 33724     22746.0                     0.0              0.0
# 46681     72740.0                     0.0              0.0
# 20863     24348.0                     0.0              0.0
# 47020     47755.0                     0.0              0.0
# 46902     53463.0                     0.0              0.0
#
#        SITIOS_PENALIZABLES  SLA_CONTRATO  TOTAL_TICKETs             TICKETs  \
# ...

# %%
#Regla para la Disponibilidad por Cliente Promedio de los incidentes de las puntas que tuvieron fallas
df_TP_SLA = df_TP_Sitios_Disp.groupby(['CLIENTE_CI','AÑO','MES']).agg({'DISPONIBILIDAD':'mean', 'SLA_CONTRATO': 'min'}).reset_index()

# %%
df_TP_SLA.sort_values('DISPONIBILIDAD', ascending=False).head()
# Out:
#                                   CLIENTE_CI   AÑO  MES  DISPONIBILIDAD  \
# 12540           SERVICIOS DE SALUD DE SONORA  2023    7           100.0
# 5472             GEM SECRETARIA DE MOVILIDAD  2023    7           100.0
# 10645              PEGASO PCS SA DE CV_TP_TP  2024    1           100.0
# 14381            UNIVERSIDAD EMILIO CARDENAS  2024    2           100.0
# 186    ADMINISTRACION DE EMPRESAS AL MENUDEO  2024    4           100.0
#
#        SLA_CONTRATO
# 12540          99.4
# 5472           99.0
# 10645          99.4
# 14381          99.4
# 186            99.4

# %%
#Regla, Dentro y Fuera de SLA POR Cliente
df_TP_SLA['SLA'] = np.where(df_TP_SLA['DISPONIBILIDAD'] >= df_TP_SLA['SLA_CONTRATO'] , 'DENTRO', 'FUERA')

# %%
df_TP_SLA = df_TP_SLA.sort_values('DISPONIBILIDAD', ascending=False)

# %%
df_TP_SLA = df_TP_SLA[['CLIENTE_CI','AÑO','MES','DISPONIBILIDAD','SLA','SLA_CONTRATO']]
df_TP_SLA.head()
# Out:
#                                   CLIENTE_CI   AÑO  MES  DISPONIBILIDAD  \
# 12540           SERVICIOS DE SALUD DE SONORA  2023    7           100.0
# 5472             GEM SECRETARIA DE MOVILIDAD  2023    7           100.0
# 10645              PEGASO PCS SA DE CV_TP_TP  2024    1           100.0
# 14381            UNIVERSIDAD EMILIO CARDENAS  2024    2           100.0
# 186    ADMINISTRACION DE EMPRESAS AL MENUDEO  2024    4           100.0
#
#           SLA  SLA_CONTRATO
# 12540  DENTRO          99.4
# 5472   DENTRO          99.0
# 10645  DENTRO          99.4
# 14381  DENTRO          99.4
# 186    DENTRO          99.4

# %%
#df_TP_SLA = pd.merge(df_TP_SLA, df_horas_mes.loc[:, ['AÑO','MES','HORAS_MES']], how='left', on=['AÑO','MES'])

# %%
#del(df_TP_SLA['HORAS_MES_x'])

# %%
#df_TP_SLA.to_csv('/content/drive/MyDrive/PORTAL_INTERNO_SLA/DOCs Procesados/SLA.csv')

# %%
df_TP_SLA.count()
# Out:
# CLIENTE_CI        14906
# AÑO               14906
# MES               14906
# DISPONIBILIDAD    14906
# SLA               14906
# SLA_CONTRATO      14906
# dtype: int64

# %%
#Regla de negocios paa Sitios Fuera de SLA
df_TP_Sitios_Fuera = df_TP_Sitios_Disp[df_TP_Sitios_Disp['SLA'] == 'FUERA']
df_TP_Sitios_Fuera.head()
df_TP_Sitios_Fuera= df_TP_Sitios_Fuera.groupby(['CLIENTE_CI','AÑO','MES'])['SLA'].count().reset_index()
df_TP_Sitios_Fuera.sort_values('SLA', ascending=False).head()
# Out:
#               CLIENTE_CI   AÑO  MES  SLA
# 2381             ELEKTRA  2023    7  245
# 2380             ELEKTRA  2023    6  238
# 6412  RED DORSAL JALISCO  2023    7  220
# 2379             ELEKTRA  2023    5  185
# 6411  RED DORSAL JALISCO  2023    6  167

# %%
df_Inc_x_Cliente = df_master.groupby(['CLIENTE_CI','FALLA','DIAGNOSTICO','SOLUCION','AÑO','MES','RESPONSABLE','AFECTACION_DE_SERVICIO'])['REF_NUM'].count().reset_index()

# %%
df_Inc_x_Cliente= df_Inc_x_Cliente.sort_values(['MES','REF_NUM'], ascending=[False,False])

# %%
df_Inc_x_Cliente.REF_NUM.count()
# Out:
# 66747

# %%
#Detalles de Incidentes de Cliente y Totalplay
df_Detalles_Incidentes = df_master[['REF_NUM','CLIENTE_CI','CLIENTE_CMDB','TIEMPO_FALLA_CTE','TIEMPO_FALLA_TPE','TIEMPO_FALLA_PROVEEDOR','TIEMPO_FALLA_TERCEROS','FECHA_INICIO','FECHA_HORA_NOTIF_SOLUCION','FECHA_CIERRE','DIAGNOSTICO','SOLUCION','RESPONSABLE','AÑO','MES','AFECTACION_DE_SERVICIO','REGION_CIUDAD','SITIOS_CRITICOS','AREA_RESOLUTORA','PRIORIDAD']]

# %%
df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = np.where(((df_Detalles_Incidentes['RESPONSABLE']=='CLIENTE') & (df_Detalles_Incidentes['AFECTACION_DE_SERVICIO']=='SI')), df_Detalles_Incidentes.TIEMPO_FALLA_CTE + df_Detalles_Incidentes.TIEMPO_FALLA_TPE + df_Detalles_Incidentes.TIEMPO_FALLA_PROVEEDOR + df_Detalles_Incidentes.TIEMPO_FALLA_TERCEROS, df_Detalles_Incidentes.TIEMPO_FALLA_CTE)
df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = pd.to_timedelta(df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'])
df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] = np.where(((df_Detalles_Incidentes['RESPONSABLE']=='TOTALPLAY') & (df_Detalles_Incidentes['AFECTACION_DE_SERVICIO']=='SI')), df_Detalles_Incidentes.TIEMPO_FALLA_TPE + df_Detalles_Incidentes.TIEMPO_FALLA_PROVEEDOR + df_Detalles_Incidentes.TIEMPO_FALLA_TERCEROS, pd.to_timedelta(0))
df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] = pd.to_timedelta(df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'])
# Out:
# <ipython-input-155-8e99a5ff8ef0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = np.where(((df_Detalles_Incidentes['RESPONSABLE']=='CLIENTE') & (df_Detalles_Incidentes['AFECTACION_DE_SERVICIO']=='SI')), df_Detalles_Incidentes.TIEMPO_FALLA_CTE + df_Detalles_Incidentes.TIEMPO_FALLA_TPE + df_Detalles_Incidentes.TIEMPO_FALLA_PROVEEDOR + df_Detalles_Incidentes.TIEMPO_FALLA_TERCEROS, df_Detalles_Incidentes.TIEMPO_FALLA_CTE)
# <ipython-input-155-8e99a5ff8ef0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'].head()
# Out:
# 0    5 days 05:05:14
# 1    0 days 02:30:24
# 2   34 days 22:59:59
# 3   35 days 01:35:01
# 4   45 days 19:23:59
# Name: TIEMPO_AFECTACION_TPE, dtype: timedelta64[ns]

# %%
 df_Detalles_Incidentes = pd.merge(df_Detalles_Incidentes, df_horas_mes.loc[:, ['AÑO','MES','HORAS_MES']], how='left', on=['AÑO','MES'])

# %%
df_Detalles_Incidentes.head()
# Out:
#    REF_NUM                       CLIENTE_CI  \
# 0  1455991       EQUIPOS_ELECTRICOS_CORE_SA
# 1  1459812     GRUPO OLARTE Y AKLE SA DE CV
# 2  1499458  POLIFORMAS PLASTICAS S.A DE C.V
# 3  1765007                             IMSS
# 4  1791272           BANCO DEL BIENESTAR_SA
#
#                               CLIENTE_CMDB TIEMPO_FALLA_CTE TIEMPO_FALLA_TPE  \
# 0               EQUIPOS ELECTRICOS CORE SA  0 days 00:00:00  5 days 05:05:14
# 1             GRUPO OLARTE Y AKLE SA DE CV  0 days 00:00:00  0 days 02:30:24
# 2          POLIFORMAS PLASTICAS S.A DE C.V  0 days 00:00:00 34 days 22:59:59
# 3  200449884_266_HGZ 10 MANZANILLO 2N_IMSS  1 days 00:00:20  0 days 02:35:02
# 4      DN8B0840_1762_PUEBLO NUEVO_N_ROUTER  0 days 00:00:00 10 days 20:24:00
#
#   TIEMPO_FALLA_PROVEEDOR TIEMPO_FALLA_TERCEROS        FECHA_INICIO  \
# 0        0 days 00:00:00       0 days 00:00:00 2022-05-20 13:20:53
# 1        0 days 00:00:00       0 days 00:00:00 2022-05-24 20:39:40
# ...

# %%
#Disponibilidad de Cliente y TP por incidente. Ajustar a números reales.
df_Detalles_Incidentes['%DISP_CLIENTE'] = np.where(((df_Detalles_Incidentes['AFECTACION_DE_SERVICIO'] == 'SI') & (df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] >='00:00:00')) , 100 - (df_Detalles_Incidentes.TIEMPO_AFECTACION_CTE / df_Detalles_Incidentes.HORAS_MES)*100, 100)
df_Detalles_Incidentes['%DISP_TPE'] = np.where(((df_Detalles_Incidentes['AFECTACION_DE_SERVICIO'] == 'SI') & (df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] >='00:00:00')), 100 - (df_Detalles_Incidentes.TIEMPO_AFECTACION_TPE / df_Detalles_Incidentes.HORAS_MES)*100, 100)
df_Detalles_Incidentes['%DISP_CLIENTE'] = np.where(df_Detalles_Incidentes['%DISP_CLIENTE'] < 0, 0, df_Detalles_Incidentes['%DISP_CLIENTE'])
df_Detalles_Incidentes['%DISP_TPE'] = np.where(df_Detalles_Incidentes['%DISP_TPE'] < 0, 0, df_Detalles_Incidentes['%DISP_TPE'])
df_Detalles_Incidentes['%DISP_TPE'] = df_Detalles_Incidentes['%DISP_TPE'].round(2)
df_Detalles_Incidentes['%DISP_CLIENTE'] = df_Detalles_Incidentes['%DISP_CLIENTE'].round(2)
df_Detalles_Incidentes['SEMANA'] = df_Detalles_Incidentes.FECHA_CIERRE.dt.isocalendar().week

# %%
df_Detalles_Incidentes = df_Detalles_Incidentes.sort_values(['AÑO','MES'], ascending=False)

# %%
df_Detalles_Incidentes = df_Detalles_Incidentes[['CLIENTE_CI','CLIENTE_CMDB','REF_NUM','TIEMPO_AFECTACION_CTE','TIEMPO_AFECTACION_TPE', 'FECHA_INICIO', 'FECHA_HORA_NOTIF_SOLUCION', 'FECHA_CIERRE', 'SOLUCION','RESPONSABLE','%DISP_CLIENTE','%DISP_TPE', 'REGION_CIUDAD', 'AÑO','MES','AFECTACION_DE_SERVICIO','SEMANA','SITIOS_CRITICOS','AREA_RESOLUTORA','DIAGNOSTICO','PRIORIDAD']]

# %%
#Regla para Disminución y aumento de Fallas Semanales
df_DFS = df_Detalles_Incidentes.groupby(['AÑO','SEMANA','CLIENTE_CI','CLIENTE_CMDB','RESPONSABLE'])['REF_NUM'].count().reset_index(name='INC_SEM')
df_DFS = df_DFS[df_DFS['CLIENTE_CI'] !='BANAMEX IWAN']
df_DRS = df_DFS[df_DFS['INC_SEM']>=2]

# %%
df_DFS = df_DFS.groupby(['AÑO','SEMANA'])['INC_SEM'].sum().reset_index()
df_DRS = df_DRS.groupby(['AÑO','SEMANA'])['INC_SEM'].sum().reset_index(name='REIN_SEM')

# %%
df_DFS = df_DFS.sort_values(['AÑO','SEMANA'], ascending=[True,True])
df_DRS = df_DRS.sort_values(['AÑO','SEMANA'], ascending=[True,True])

# %%
df_DFS = pd.merge(df_DFS, df_DRS , how='left', on=['AÑO','SEMANA'])

# %%
df_DFS.head(30)
# Out:
#      AÑO  SEMANA  INC_SEM  REIN_SEM
# 0   2023      17        1       NaN
# 1   2023      18     2211     617.0
# 2   2023      19     2381     724.0
# 3   2023      20     2507     772.0
# 4   2023      21     2480     726.0
# 5   2023      22     2348     714.0
# 6   2023      23     2242     577.0
# 7   2023      24     2695     950.0
# 8   2023      25     2525     776.0
# 9   2023      26     2584     722.0
# 10  2023      27     3261     926.0
# 11  2023      28     2965     954.0
# 12  2023      29     2681     730.0
# 13  2023      30     2653     820.0
# 14  2023      31     2596     704.0
# 15  2023      32     2749     805.0
# 16  2023      33     2460     653.0
# 17  2023      34     2697     701.0
# 18  2023      35     2695     893.0
# 19  2023      36     2619     740.0
# 20  2023      37     2456     737.0
# 21  2023      38     2491     730.0
# 22  2023      39     2396     641.0
# 23  2023      40     2397     717.0
# 24  2023      41     2599     767.0
# ...

# %%
import datetime
df_Detalles_Incidentes = df_Detalles_Incidentes.drop_duplicates()
df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'].dt.total_seconds()
df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'].dt.total_seconds()

#df_Detalles_Incidentes_2022 = df_Detalles_Incidentes[(df_Detalles_Incidentes['FECHA_CIERRE'] >= "2022-01-01")]
#df_Detalles_Incidentes_2022 = df_Detalles_Incidentes_2022.drop_duplicates()
#df_Detalles_Incidentes_01_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 1)]
#df_Detalles_Incidentes_02_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 2)]
#df_Detalles_Incidentes_03_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 3)]
#df_Detalles_Incidentes_04_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 4)]
#df_Detalles_Incidentes_05_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 5)]
#df_Detalles_Incidentes_06_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 6)]
#df_Detalles_Incidentes_07_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 7)]
#df_Detalles_Incidentes_08_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 8)]
#df_Detalles_Incidentes_09_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 9)]
#df_Detalles_Incidentes_10_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 10)]
#df_Detalles_Incidentes_11_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 11)]
#df_Detalles_Incidentes_12_2022 = df_Detalles_Incidentes_2022[(df_Detalles_Incidentes_2022['MES'] == 12)]

# df_Detalles_Incidentes_2021 = df_Detalles_Incidentes[(df_Detalles_Incidentes['FECHA_CIERRE'] >= "2021-01-01") & (df_Detalles_Incidentes['FECHA_CIERRE'] <= "2021-12-31")]
# df_Detalles_Incidentes_2021 = df_Detalles_Incidentes_2021.drop_duplicates()
# df_Detalles_Incidentes_01_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 1)]
# df_Detalles_Incidentes_02_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 2)]
# df_Detalles_Incidentes_03_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 3)]
# df_Detalles_Incidentes_04_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 4)]
# df_Detalles_Incidentes_05_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 5)]
# df_Detalles_Incidentes_06_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 6)]
# df_Detalles_Incidentes_07_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 7)]
# df_Detalles_Incidentes_08_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 8)]
# df_Detalles_Incidentes_09_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 9)]
# df_Detalles_Incidentes_10_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 10)]
# df_Detalles_Incidentes_11_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 11)]
# df_Detalles_Incidentes_12_2021 = df_Detalles_Incidentes_2021[(df_Detalles_Incidentes_2021['MES'] == 12)]

# df_Detalles_Incidentes_2020 = df_Detalles_Incidentes[(df_Detalles_Incidentes['FECHA_CIERRE'] < "2021-01-01")]
# df_Detalles_Incidentes_2020 = df_Detalles_Incidentes_2020.drop_duplicates()
# df_Detalles_Incidentes_01_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 1)]
# df_Detalles_Incidentes_02_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 2)]
# df_Detalles_Incidentes_03_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 3)]
# df_Detalles_Incidentes_04_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 4)]
# df_Detalles_Incidentes_05_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 5)]
# df_Detalles_Incidentes_06_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 6)]
# df_Detalles_Incidentes_07_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 7)]
# df_Detalles_Incidentes_08_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 8)]
# df_Detalles_Incidentes_09_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 9)]
# df_Detalles_Incidentes_10_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 10)]
# df_Detalles_Incidentes_11_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 11)]
# df_Detalles_Incidentes_12_2020 = df_Detalles_Incidentes_2020[(df_Detalles_Incidentes_2020['MES'] == 12)]

df_Detalles_Incidentes_2023 = df_Detalles_Incidentes[(df_Detalles_Incidentes['FECHA_CIERRE'] >= "2023-01-01")]
df_Detalles_Incidentes_2023 = df_Detalles_Incidentes_2023.drop_duplicates()
df_Detalles_Incidentes_01_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 1)]
df_Detalles_Incidentes_02_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 2)]
df_Detalles_Incidentes_03_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 3)]
df_Detalles_Incidentes_04_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 4)]
df_Detalles_Incidentes_05_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 5)]
df_Detalles_Incidentes_06_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 6)]
df_Detalles_Incidentes_07_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 7)]
df_Detalles_Incidentes_08_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 8)]
df_Detalles_Incidentes_09_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 9)]
df_Detalles_Incidentes_10_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 10)]
df_Detalles_Incidentes_11_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 11)]
df_Detalles_Incidentes_12_2023 = df_Detalles_Incidentes_2023[(df_Detalles_Incidentes_2023['MES'] == 12)]

import datetime
now = datetime.datetime.now()
now.month

#df_Detalles_Incidentes_2021 = df_Detalles_Incidentes_2021[df_Detalles_Incidentes_2021['MES'] >= now.month]

df_Detalles_Incidentes_Gral = pd.concat([df_Detalles_Incidentes_2023])
# Out:
# <ipython-input-167-d37caa298021>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'].dt.total_seconds()
# <ipython-input-167-d37caa298021>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'].dt.total_seconds()

# %%
df_Detalles_Incidentes_Gral[df_Detalles_Incidentes_Gral['REF_NUM']==1398679]
# Out:
# Empty DataFrame
# Columns: [CLIENTE_CI, CLIENTE_CMDB, REF_NUM, TIEMPO_AFECTACION_CTE, TIEMPO_AFECTACION_TPE, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, SOLUCION, RESPONSABLE, %DISP_CLIENTE, %DISP_TPE, REGION_CIUDAD, AÑO, MES, AFECTACION_DE_SERVICIO, SEMANA, SITIOS_CRITICOS, AREA_RESOLUTORA, DIAGNOSTICO, PRIORIDAD]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_Detalles_Incidentes = df_Detalles_Incidentes.groupby(['CLIENTE_CI','AÑO','MES','RESPONSABLE']).agg({'TIEMPO_AFECTACION_CTE':'sum', 'TIEMPO_AFECTACION_TPE': 'sum', '%DISP_CLIENTE': 'mean', '%DISP_TPE': 'mean'}).reset_index()

# %%
df_Detalles_Incidentes.sort_values('TIEMPO_AFECTACION_TPE', ascending=False).head()
# Out:
#                                               CLIENTE_CI   AÑO  MES  \
# 1643                              BANCO DEL BIENESTAR_SA  2023    7
# 19256  Secretaría de Seguridad Ciudadana Municipio de...  2023    9
# 1645                              BANCO DEL BIENESTAR_SA  2023    8
# 1641                              BANCO DEL BIENESTAR_SA  2023    6
# 1659                              BANCO DEL BIENESTAR_SA  2024    3
#
#       RESPONSABLE  TIEMPO_AFECTACION_CTE  TIEMPO_AFECTACION_TPE  \
# 1643    TOTALPLAY             38739571.0            208777637.0
# 19256   TOTALPLAY              5019280.0            191635470.0
# 1645    TOTALPLAY             31456571.0            163580450.0
# 1641    TOTALPLAY             45058896.0            139210676.0
# 1659    TOTALPLAY              9314144.0            134474473.0
#
#        %DISP_CLIENTE  %DISP_TPE
# 1643       90.040903  54.479444
# 19256      98.286372  39.061504
# 1645       90.319250  57.154750
# 1641       85.324870  57.440261
# ...

# %%
# df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_CTE'].dt.total_seconds() / (60 * 60)
# df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'] = df_Detalles_Incidentes['TIEMPO_AFECTACION_TPE'].dt.total_seconds() / (60 * 60)

# %%
df_Detalles_Incidentes.sort_values('TIEMPO_AFECTACION_TPE', ascending=False).head()
# Out:
#                                               CLIENTE_CI   AÑO  MES  \
# 1643                              BANCO DEL BIENESTAR_SA  2023    7
# 19256  Secretaría de Seguridad Ciudadana Municipio de...  2023    9
# 1645                              BANCO DEL BIENESTAR_SA  2023    8
# 1641                              BANCO DEL BIENESTAR_SA  2023    6
# 1659                              BANCO DEL BIENESTAR_SA  2024    3
#
#       RESPONSABLE  TIEMPO_AFECTACION_CTE  TIEMPO_AFECTACION_TPE  \
# 1643    TOTALPLAY             38739571.0            208777637.0
# 19256   TOTALPLAY              5019280.0            191635470.0
# 1645    TOTALPLAY             31456571.0            163580450.0
# 1641    TOTALPLAY             45058896.0            139210676.0
# 1659    TOTALPLAY              9314144.0            134474473.0
#
#        %DISP_CLIENTE  %DISP_TPE
# 1643       90.040903  54.479444
# 19256      98.286372  39.061504
# 1645       90.319250  57.154750
# 1641       85.324870  57.440261
# ...

# %%
#df_Detalles_Incidentes.to_excel('/content/drive/MyDrive/PORTAL_INTERNO_SLA/DOCs Procesados/Detalles_Incidentes.xlsx', index=False)
#df_Detalles_Incidentes.to_html('/content/drive/MyDrive/PORTAL_INTERNO_SLA/DOCs Procesados/Detalles_Incidentes.html', index=False)

# %%
Fecha_act = df_Detalles_Incidentes_2023.sort_values('FECHA_CIERRE', ascending=False).head(1)

# %%
#Regla para Detalles de las últimas 4 semanas TP
#df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_2021[df_Detalles_Incidentes_2021['SEMANA'] < 53]
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_2023
#df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem[df_Detalles_Incidentes_4_sem['SEMANA'] >= (df_Detalles_Incidentes_4_sem.SEMANA.max()-3)]
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem[df_Detalles_Incidentes_4_sem['RESPONSABLE'] == 'TOTALPLAY']

#Frecuencia de incidentes de las últimas 4 semanas.
df_Detalles_Incidentes_4_sem["FREC"] = df_Detalles_Incidentes_4_sem.groupby(['CLIENTE_CI','CLIENTE_CMDB'])['REF_NUM'].transform('count')
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem.sort_values(['FREC', 'FECHA_INICIO'], ascending=[False, False])
#df_Detalles_Incidentes_4_sem["MTTR"] = (df_Detalles_Incidentes_4_sem['FECHA_HORA_NOTIF_SOLUCION'] - df_Detalles_Incidentes_4_sem['FECHA_INICIO'])
#df_Detalles_Incidentes_4_sem["MTTR"] = df_Detalles_Incidentes_4_sem["MTTR"].dt.total_seconds()
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem[['CLIENTE_CI',	'CLIENTE_CMDB',	'REF_NUM',	'TIEMPO_AFECTACION_CTE',	'TIEMPO_AFECTACION_TPE',	'FECHA_INICIO',	'FECHA_HORA_NOTIF_SOLUCION',	'FECHA_CIERRE',	'SOLUCION',	'RESPONSABLE',	'%DISP_CLIENTE',	'%DISP_TPE',	'REGION_CIUDAD',	'FREC', 'SITIOS_CRITICOS','DIAGNOSTICO','AREA_RESOLUTORA']]
# Out:
# <ipython-input-175-79cf77deb64f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Detalles_Incidentes_4_sem["FREC"] = df_Detalles_Incidentes_4_sem.groupby(['CLIENTE_CI','CLIENTE_CMDB'])['REF_NUM'].transform('count')

# %%
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem.sort_values(['FREC','CLIENTE_CI','CLIENTE_CMDB','FECHA_INICIO'], ascending=[False, True, True, False])
df_Detalles_Incidentes_4_sem = df_Detalles_Incidentes_4_sem.drop_duplicates()

# %%
df_TOP= df_Detalles_Incidentes_4_sem.groupby(['CLIENTE_CI','CLIENTE_CMDB'])['REF_NUM'].count().reset_index(name='FREC')
df_TOP = df_TOP.sort_values(['CLIENTE_CI','FREC'], ascending=[True, False])

# %%
df_TOP.head()
# Out:
#                                           CLIENTE_CI  \
# 0
# 1                                  Comentarios: test
# 2                     INMOBILIARIA JEVI SA DE CV._TP
# 3                            LABORATORIOS SILANES_TP
# 4   OPERADORA DE ESPECTACULOS DEPORTIVOS S.A. DE ...
#
#                                         CLIENTE_CMDB  FREC
# 0          TFE-VD-OTR38403 K679-I Centro Maya_Kiosco     1
# 1                                  Comentarios: test     1
# 2                     INMOBILIARIA JEVI SA DE CV._TP     1
# 3                                       0200636673-P     3
# 4  0200471287_EC_OPERADORA_DE_ESPECTACULOS_DEPORT...     1

# %%
df_Cat_CI= df_master.groupby(['CLIENTE_CI','CLIENTE_CMDB','REGION_CIUDAD'])['REF_NUM'].count().reset_index()
df_Cat_CI.to_csv('CAT_CI_REGION.csv')

# %%
df_Cat_CI.nunique()
# Out:
# CLIENTE_CI        5201
# CLIENTE_CMDB     40970
# REGION_CIUDAD       81
# REF_NUM             75
# dtype: int64

# %%
df_CAT_Sitios_Criticos =  df_master.groupby(['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES','SITIOS_CRITICOS'])['REF_NUM'].count().reset_index()

# %%
df_disp_men = (pd.crosstab([df_TP_SLA.CLIENTE_CI], [df_TP_SLA['AÑO'], df_TP_SLA.MES], values=df_TP_SLA.DISPONIBILIDAD, aggfunc='mean').round(3)).reset_index()
df_disp_men.fillna(100, inplace=True)
df_disp_men = (df_disp_men.set_index(['CLIENTE_CI'])
   .rename_axis(['AÑO','MES'], axis=1)
   .stack(['AÑO','MES'])
   #.unstack()
   .reset_index())
df_disp_men = df_disp_men.rename(columns={0: 'DISPONIBILIDAD'})
df_disp_men = pd.merge(df_disp_men, df_Cat_SLA.loc[:, ['CLIENTE_CI','SLA_CONTRATO_CI']], how='left', on=['CLIENTE_CI'])
df_disp_men = df_disp_men.rename(columns={'SLA_CONTRATO_CI': 'SLA_CONTRATO'})
df_disp_men.SLA_CONTRATO.fillna(99.4, inplace=True)
df_disp_men['SLA'] = np.where(df_disp_men['DISPONIBILIDAD'] >= df_disp_men['SLA_CONTRATO'],'DENTRO', 'FUERA')
#df_disp_men['AÑO'] = 2021
df_disp_men = df_disp_men.drop_duplicates()

# %%
df_disp_men.sort_values('AÑO', ascending=False).head()
# Out:
#                                       CLIENTE_CI   AÑO  MES  DISPONIBILIDAD  \
# 64206             i-TRACK SYSTEMS DEVELOPMENT_TP  2024    5          100.00
# 49814                    QUALITY K S DE RL DE CV  2024    4          100.00
# 23421                           FUNDACION AZTECA  2024    1           99.72
# 49800  QUALITAS COMPAÑÍA DE SEGUROS S.A. DE C.V.  2024    3          100.00
# 49801  QUALITAS COMPAÑÍA DE SEGUROS S.A. DE C.V.  2024    4           99.67
#
#        SLA_CONTRATO     SLA
# 64206          99.4  DENTRO
# 49814          99.4  DENTRO
# 23421          99.4  DENTRO
# 49800          99.4  DENTRO
# 49801          99.4  DENTRO

# %%
df_disp_men_sitios = (pd.crosstab([df_TP_Sitios_Disp.CLIENTE_CI, df_TP_Sitios_Disp.CLIENTE_CMDB], [df_TP_Sitios_Disp['AÑO'], df_TP_Sitios_Disp.MES], values=df_TP_Sitios_Disp.DISPONIBILIDAD, aggfunc='mean').round(3)).reset_index()
df_disp_men_sitios.fillna(100, inplace=True)
df_disp_men_sitios = (df_disp_men_sitios.set_index(['CLIENTE_CI', 'CLIENTE_CMDB'])
   .rename_axis(['AÑO','MES'], axis=1)
   .stack(['AÑO','MES'])
   #.unstack()
   .reset_index())
df_disp_men_sitios = df_disp_men_sitios.rename(columns={0: 'DISPONIBILIDAD'})
df_disp_men_sitios = pd.merge(df_disp_men_sitios, df_Cat_SLA_PUNTAS.loc[:, ['CLIENTE_CI','CLIENTE_CMDB','SLA_CONTRATO_PUNTA']], how='left', on=['CLIENTE_CI','CLIENTE_CMDB'])
df_disp_men_sitios = df_disp_men_sitios.rename(columns={'SLA_CONTRATO_PUNTA': 'SLA_CONTRATO'})
#df_disp_men_sitios.SLA_CONTRATO.fillna(99.4, inplace=True)
df_disp_men_sitios['SLA'] = np.where(df_disp_men_sitios['DISPONIBILIDAD'] >= df_disp_men_sitios['SLA_CONTRATO'],'DENTRO', 'FUERA')
df_disp_men_sitios = pd.merge(df_disp_men_sitios, df_Cat_Criticos.loc[:, ['CLIENTE_CMDB','SITIOS_CRITICOS']], how='left', on=['CLIENTE_CMDB'])
df_disp_men_sitios.fillna(0, inplace=True)
df_disp_men_sitios = df_disp_men_sitios.drop_duplicates()

# %%
df_disp_men_sitios.head()
# Out:
#   CLIENTE_CI                               CLIENTE_CMDB   AÑO  MES  \
# 0             TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023    5
# 1             TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023    6
# 2             TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023    7
# 3             TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023    8
# 4             TFE-VD-OTR38403 K679-I Centro Maya_Kiosco  2023    9
#
#    DISPONIBILIDAD  SLA_CONTRATO    SLA  SITIOS_CRITICOS
# 0           100.0           0.0  FUERA              0.0
# 1           100.0           0.0  FUERA              0.0
# 2           100.0           0.0  FUERA              0.0
# 3           100.0           0.0  FUERA              0.0
# 4           100.0           0.0  FUERA              0.0

# %%
#Crear libros y hojas de GSheets.

#sh = gc.create('Histórico_SLA')
#sh2 = gc.create('Detalle_Incidentes_2021')
#sh3 = gc.create('Detalle_Incidentes_2020')
#sh4 = gc.create('Inconsistencias')
#sh5 = gc.create('Incidentes_x_Clientes')

'''
spreadsheet = gc.open('Histórico_SLA').add_worksheet(title="Hitorico_SLA", rows=0, cols=0)
spreadsheet2 = gc.open('Histórico_SLA').add_worksheet(title="Sitios_Fuera_SLA", rows=0, cols=0)
spreadsheet3 = gc.open('Histórico_SLA').add_worksheet(title="Disponibilidad_x_Sitio", rows=0, cols=0)
spreadsheet4 = gc.open('Histórico_SLA').add_worksheet(title="Reincidencias_TP", rows=0, cols=0)
spreadsheet5 = gc.open('Incidentes_x_Clientes').add_worksheet(title="Incidentes_x_Clientes", rows=0, cols=0)
spreadsheet8 = gc.open('Inconsistencias').add_worksheet(title="Inconsistencias", rows=0, cols=0)
spreadsheet9 = gc.open('Histórico_SLA').add_worksheet(title="Detalle_Incidentes_CI", rows=0, cols=0)

#spreadsheet6 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Histórico_Incidentes_2021", rows=0, cols=0) # Se sepan por mes ignorar esta línea
spreadsheet2021_01 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Enero_2021", rows=0, cols=0)
spreadsheet2021_02 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Febrero_2021", rows=0, cols=0)
spreadsheet2021_03 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Marzo_2021", rows=0, cols=0)
spreadsheet2021_04 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Abril_2021", rows=0, cols=0)
spreadsheet2021_05 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Mayo_2021", rows=0, cols=0)
spreadsheet2021_06 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Junio_2021", rows=0, cols=0)
spreadsheet2021_07 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Julio_2021", rows=0, cols=0)
spreadsheet2021_08 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Agosto_2021", rows=0, cols=0)
spreadsheet2021_09 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Septiembre_2021", rows=0, cols=0)
spreadsheet2021_10 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Octubre_2021", rows=0, cols=0)
spreadsheet2021_11 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Noviembre_2021", rows=0, cols=0)
spreadsheet2021_12 = gc.open('Detalle_Incidentes_2021').add_worksheet(title="Diciembre_2021", rows=0, cols=0)

#spreadsheet7 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Histórico_Incidentes_2020", rows=0, cols=0) # Se sepan por mes ignorar esta línea
spreadsheet2020_01 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Enero_2020", rows=0, cols=0)
spreadsheet2020_02 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Febrero_2020", rows=0, cols=0)
spreadsheet2020_03 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Marzo_2020", rows=0, cols=0)
spreadsheet2020_04 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Abril_2020", rows=0, cols=0)
spreadsheet2020_05 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Mayo_2020", rows=0, cols=0)
spreadsheet2020_06 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Junio_2020", rows=0, cols=0)
spreadsheet2020_07 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Julio_2020", rows=0, cols=0)
spreadsheet2020_08 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Agosto_2020", rows=0, cols=0)
spreadsheet2020_09 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Septiembre_2020", rows=0, cols=0)
spreadsheet2020_10 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Octubre_2020", rows=0, cols=0)
spreadsheet2020_11 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Noviembre_2020", rows=0, cols=0)
spreadsheet2020_12 = gc.open('Detalle_Incidentes_2020').add_worksheet(title="Diciembre_2020", rows=0, cols=0)


sh8 = gc.create('Detalle_Incidentes_2022')

spreadsheet2022 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Histórico_Incidentes_2022", rows=0, cols=0) # Se separan por mes ignorar esta línea
spreadsheet2022_01 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Enero_2022", rows=0, cols=0)
spreadsheet2022_02 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Febrero_2022", rows=0, cols=0)
spreadsheet2022_03 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Marzo_2022", rows=0, cols=0)
spreadsheet2022_04 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Abril_2022", rows=0, cols=0)
spreadsheet2022_05 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Mayo_2022", rows=0, cols=0)
spreadsheet2022_06 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Junio_2022", rows=0, cols=0)
spreadsheet2022_07 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Julio_2022", rows=0, cols=0)
spreadsheet2022_08 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Agosto_2022", rows=0, cols=0)
spreadsheet2022_09 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Septiembre_2022", rows=0, cols=0)
spreadsheet2022_10 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Octubre_2022", rows=0, cols=0)
spreadsheet2022_11 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Noviembre_2022", rows=0, cols=0)
spreadsheet2022_12 = gc.open('Detalle_Incidentes_2022').add_worksheet(title="Diciembre_2022", rows=0, cols=0)
'''

#------------------------------------Descarmar la sección de abajo para actualizar archivos----------------------------------------------------------------

#Abrir Archivos y hojas existentes
spreadsheet = gc.open('Histórico_SLA').worksheet("Hitorico_SLA")
spreadsheet2 = gc.open('Histórico_SLA').worksheet("Sitios_Fuera_SLA")
spreadsheet3 = gc.open('Histórico_SLA').worksheet("Disponibilidad_x_Sitio")
spreadsheet4 = gc.open('Histórico_SLA').worksheet("Reincidencias_TP")
spreadsheet5 = gc.open('Incidentes_x_Clientes').worksheet("Incidentes_x_Clientes")
spreadsheet8 = gc.open('Inconsistencias').worksheet("Inconsistencias")
spreadsheet9 = gc.open('Histórico_SLA').worksheet("Detalle_Incidentes_CI")
spreadsheet.clear()
spreadsheet2.clear()
spreadsheet3.clear()
spreadsheet4.clear()
spreadsheet5.clear()
spreadsheet8.clear()
spreadsheet9.clear()


'''
#spreadsheet7 = gc.open('Detalle_Incidentes_2020').worksheet("Histórico_Incidentes_2020") # Se seapan por mes, ignorar esta linea
spreadsheet2020_01 = gc.open('Detalle_Incidentes_2020').worksheet("Enero_2020")
spreadsheet2020_02 = gc.open('Detalle_Incidentes_2020').worksheet("Febrero_2020")
spreadsheet2020_03 = gc.open('Detalle_Incidentes_2020').worksheet("Marzo_2020")
spreadsheet2020_04 = gc.open('Detalle_Incidentes_2020').worksheet("Abril_2020")
spreadsheet2020_05 = gc.open('Detalle_Incidentes_2020').worksheet("Mayo_2020")
spreadsheet2020_06 = gc.open('Detalle_Incidentes_2020').worksheet("Junio_2020")
spreadsheet2020_07 = gc.open('Detalle_Incidentes_2020').worksheet("Julio_2020")
spreadsheet2020_08 = gc.open('Detalle_Incidentes_2020').worksheet("Agosto_2020")
spreadsheet2020_09 = gc.open('Detalle_Incidentes_2020').worksheet("Septiembre_2020")
spreadsheet2020_10 = gc.open('Detalle_Incidentes_2020').worksheet("Octubre_2020")
spreadsheet2020_11 = gc.open('Detalle_Incidentes_2020').worksheet("Noviembre_2020")
spreadsheet2020_12 = gc.open('Detalle_Incidentes_2020').worksheet("Diciembre_2020")


spreadsheet6 = gc.open('Detalle_Incidentes_2021').worksheet("Histórico_Incidentes_2021")
spreadsheet6.clear()
spreadsheet2021_01 = gc.open('Detalle_Incidentes_2021').worksheet("Enero_2021")
spreadsheet2021_02 = gc.open('Detalle_Incidentes_2021').worksheet("Febrero_2021")
spreadsheet2021_03 = gc.open('Detalle_Incidentes_2021').worksheet("Marzo_2021")
spreadsheet2021_04 = gc.open('Detalle_Incidentes_2021').worksheet("Abril_2021")
spreadsheet2021_05 = gc.open('Detalle_Incidentes_2021').worksheet("Mayo_2021")
spreadsheet2021_06 = gc.open('Detalle_Incidentes_2021').worksheet("Junio_2021")
spreadsheet2021_07 = gc.open('Detalle_Incidentes_2021').worksheet("Julio_2021")
spreadsheet2021_08 = gc.open('Detalle_Incidentes_2021').worksheet("Agosto_2021")
spreadsheet2021_09 = gc.open('Detalle_Incidentes_2021').worksheet("Septiembre_2021")
spreadsheet2021_10 = gc.open('Detalle_Incidentes_2021').worksheet("Octubre_2021")
spreadsheet2021_11 = gc.open('Detalle_Incidentes_2021').worksheet("Noviembre_2021")
spreadsheet2021_12 = gc.open('Detalle_Incidentes_2021').worksheet("Diciembre_2021")

spreadsheet2021_01.clear()
spreadsheet2021_02.clear()
spreadsheet2021_03.clear()
spreadsheet2021_04.clear()
spreadsheet2021_05.clear()
spreadsheet2021_06.clear()
spreadsheet2021_07.clear()
spreadsheet2021_08.clear()
spreadsheet2021_09.clear()
spreadsheet2021_10.clear()
spreadsheet2021_11.clear()
spreadsheet2021_12.clear()
'''

#spreadsheet2022 = gc.open('Detalle_Incidentes_2022').worksheet("Histórico_Incidentes_2022")
#spreadsheet2022.clear()
#spreadsheet2022_01 = gc.open('Detalle_Incidentes_2022').worksheet("Enero_2022")
#spreadsheet2022_02 = gc.open('Detalle_Incidentes_2022').worksheet("Febrero_2022")
#spreadsheet2022_03 = gc.open('Detalle_Incidentes_2022').worksheet("Marzo_2022")
#spreadsheet2022_04 = gc.open('Detalle_Incidentes_2022').worksheet("Abril_2022")
#spreadsheet2022_05 = gc.open('Detalle_Incidentes_2022').worksheet("Mayo_2022")
#spreadsheet2022_06 = gc.open('Detalle_Incidentes_2022').worksheet("Junio_2022")
#spreadsheet2022_07 = gc.open('Detalle_Incidentes_2022').worksheet("Julio_2022")
#spreadsheet2022_08 = gc.open('Detalle_Incidentes_2022').worksheet("Agosto_2022")
#spreadsheet2022_09 = gc.open('Detalle_Incidentes_2022').worksheet("Septiembre_2022")
#spreadsheet2022_10 = gc.open('Detalle_Incidentes_2022').worksheet("Octubre_2022")
#spreadsheet2022_11 = gc.open('Detalle_Incidentes_2022').worksheet("Noviembre_2022")
#spreadsheet2022_12 = gc.open('Detalle_Incidentes_2022').worksheet("Diciembre_2022")

#spreadsheet2022_01.clear()
#spreadsheet2022_02.clear()
#spreadsheet2022_03.clear()
#spreadsheet2022_04.clear()
#spreadsheet2022_05.clear()
#spreadsheet2022_06.clear()
#spreadsheet2022_07.clear()
#spreadsheet2022_08.clear()
#spreadsheet2022_09.clear()
#spreadsheet2022_10.clear()
#spreadsheet2022_11.clear()
#spreadsheet2022_12.clear()

#spreadsheet2023_01.clear()
#spreadsheet2023_02.clear()
#spreadsheet2023_03.clear()
#spreadsheet2023_04.clear()
#spreadsheet2023_05.clear()
#spreadsheet2023_06.clear()
#spreadsheet2023_07.clear()
#spreadsheet2023_08.clear()
#spreadsheet2023_09.clear()
#spreadsheet2023_10.clear()
#spreadsheet2023_11.clear()
#spreadsheet2023_12.clear()

spreadsheetGral = gc.open('Detalle_Incidentes_Gral').worksheet("Histórico_Incidentes_Gral")
spreadsheetGral.clear()



#Actualizar información de los DFs a GSheets

gd.set_with_dataframe(spreadsheet, df_disp_men, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2, df_TP_Sitios_Fuera, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet3, df_TP_Sitios_Disp, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet4, df_reincidencias_TP, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet5, df_Inc_x_Cliente, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet8, df_tiempos_cero, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet9, df_Detalles_Incidentes, row=1, col=1, include_index=False, include_column_header=True)


'''
#gd.set_with_dataframe(spreadsheet7, df_Detalles_Incidentes_2020, row=1, col=1, include_index=False, include_column_header=True) #Se separan por mes ignorr esta línea
gd.set_with_dataframe(spreadsheet2020_01, df_Detalles_Incidentes_01_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_02, df_Detalles_Incidentes_02_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_03, df_Detalles_Incidentes_03_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_04, df_Detalles_Incidentes_04_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_05, df_Detalles_Incidentes_05_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_06, df_Detalles_Incidentes_06_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_07, df_Detalles_Incidentes_07_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_08, df_Detalles_Incidentes_08_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_09, df_Detalles_Incidentes_09_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_10, df_Detalles_Incidentes_10_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_11, df_Detalles_Incidentes_11_2020, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2020_12, df_Detalles_Incidentes_12_2020, row=1, col=1, include_index=False, include_column_header=True)


gd.set_with_dataframe(spreadsheet6, df_Detalles_Incidentes_2021, row=1, col=1, include_index=False, include_column_header=True) #Se separan por mes ignorar esta línea
gd.set_with_dataframe(spreadsheet2021_01, df_Detalles_Incidentes_01_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_02, df_Detalles_Incidentes_02_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_03, df_Detalles_Incidentes_03_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_04, df_Detalles_Incidentes_04_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_05, df_Detalles_Incidentes_05_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_06, df_Detalles_Incidentes_06_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_07, df_Detalles_Incidentes_07_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_08, df_Detalles_Incidentes_08_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_09, df_Detalles_Incidentes_09_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_10, df_Detalles_Incidentes_10_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_11, df_Detalles_Incidentes_11_2021, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet2021_12, df_Detalles_Incidentes_12_2021, row=1, col=1, include_index=False, include_column_header=True)
'''

#gd.set_with_dataframe(spreadsheet2022, df_Detalles_Incidentes_2022, row=1, col=1, include_index=False, include_column_header=True) #Se separan por mes ignorar esta línea
#gd.set_with_dataframe(spreadsheet2022_01, df_Detalles_Incidentes_01_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_02, df_Detalles_Incidentes_02_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_03, df_Detalles_Incidentes_03_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_04, df_Detalles_Incidentes_04_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_05, df_Detalles_Incidentes_05_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_06, df_Detalles_Incidentes_06_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_07, df_Detalles_Incidentes_07_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_08, df_Detalles_Incidentes_08_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_09, df_Detalles_Incidentes_09_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_10, df_Detalles_Incidentes_10_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_11, df_Detalles_Incidentes_11_2022, row=1, col=1, include_index=False, include_column_header=True)
#gd.set_with_dataframe(spreadsheet2022_12, df_Detalles_Incidentes_12_2022, row=1, col=1, include_index=False, include_column_header=True)



gd.set_with_dataframe(spreadsheetGral, df_Detalles_Incidentes_Gral, row=1, col=1, include_index=False, include_column_header=True) #Se separan por mes ignorar esta línea


#Obtener la fecha del úmtimo registro del día o corte.
# #spreadsheet10 = gc.open('Histórico_SLA').add_worksheet(title="Fecha_Actualizacion", rows=0, cols=0)
# spreadsheet10 = gc.open('Histórico_SLA').worksheet("Fecha_Actualizacion")
# spreadsheet10.clear()
# gd.set_with_dataframe(spreadsheet10, Fecha_act, row=1, col=1, include_index=False, include_column_header=True)


#Últimas 4 semanas
#sh6 = gc.create('Ultimas 4 semanas')
#spreadsheet11 = gc.open('Ultimas 4 semanas').add_worksheet(title="Ultimas 4 semanas", rows=0, cols=0)
spreadsheet11 = gc.open('Ultimas 4 semanas').worksheet("Ultimas 4 semanas")
gd.set_with_dataframe(spreadsheet11, df_Detalles_Incidentes_4_sem, row=1, col=1, include_index=False, include_column_header=True)

#Sitios Top últimas 4 semanas
#sh7 = gc.create('Ultimas 4 semanas')
#spreadsheet12 = gc.open('Ultimas 4 semanas').add_worksheet(title="Top", rows=0, cols=0)
spreadsheet12 = gc.open('Ultimas 4 semanas').worksheet("Top")
gd.set_with_dataframe(spreadsheet12, df_TOP, row=1, col=1, include_index=False, include_column_header=True)

#Incidentes y Reicidencias Semanales por semana
#spreadsheet13 = gc.open('Ultimas 4 semanas').add_worksheet(title="DFS", rows=0, cols=0)
spreadsheet13 = gc.open('Ultimas 4 semanas').worksheet("DFS")
gd.set_with_dataframe(spreadsheet13, df_DFS, row=1, col=1, include_index=False, include_column_header=True)


#Cat Clientes CI
#spreadsheet14 = gc.open('Ultimas 4 semanas').add_worksheet(title="CAT_CI", rows=0, cols=0)
#spreadsheet14= gc.open('Histórico_SLA').worksheet("CAT_CI")
#gd.set_with_dataframe(spreadsheet14, df_Cat_CI, row=1, col=1, include_index=False, include_column_header=True)
'''
#Cat Sitios Críticos
#spreadsheet15 = gc.open('Ultimas 4 semanas').add_worksheet(title="CAT_Criticos", rows=0, cols=0)
spreadsheet15= gc.open('Ultimas 4 semanas').worksheet("CAT_Criticos")
gd.set_with_dataframe(spreadsheet15, df_CAT_Sitios_Criticos, row=1, col=1, include_index=False, include_column_header=True)
'''

#sh6 = gc.create('Disp_men_sitios')
#spreadsheet16 = gc.open('Disp_men_sitios').add_worksheet(title="Disp_men_sitio", rows=0, cols=0)
spreadsheet16 = gc.open('Disp_men_sitios').worksheet("Disp_men_sitios")
spreadsheet16.clear()
gd.set_with_dataframe(spreadsheet16, df_disp_men_sitios, row=1, col=1, include_index=False, include_column_header=True)

#sh7 = gc.create('MTTR_MTBF')
#spreadsheet17 = gc.open('MTTR_MTBF').add_worksheet(title="MTTR_MTBF", rows=0, cols=0)
spreadsheet17 = gc.open('MTTR_MTBF').worksheet("MTTR_MTBF")
spreadsheet17.clear()
gd.set_with_dataframe(spreadsheet17, df_mttr_mtbf, row=1, col=1, include_index=False, include_column_header=True)


#spreadsheet18 = gc.open('MTTR_MTBF').add_worksheet(title="TICKETs_Padre", rows=0, cols=0)
spreadsheet18 = gc.open('MTTR_MTBF').worksheet("TICKETs_Padre")
spreadsheet18.clear()
gd.set_with_dataframe(spreadsheet18, df_tickets_padre, row=1, col=1, include_index=False, include_column_header=True)

# %%
df_master[df_master['REF_NUM']==1141305]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, NOMBRE, ZES_PROACTIVO_REACTIVO, SERVICIO_AFECTADO, FALLA, ESTATUS, MOTIVO, GRUPO_ACTUAL, PRIORIDAD, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, DURACION, DIAGNOSTICO, SOLUCION, AREA_RESOLUTORA, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, AFECTACION_DE_SERVICIO, RESUMEN, DESCRIPCION, TICKET_SISTEMA_EXTERNO, REGION_CIUDAD, TICKET_PADRE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, CLIENTE_CI, CLIENTE_CMDB, IP_CMDB, TIEMPO_ACTIVIDAD, DIAGNOSTICO_INCIAL, FECHA_HORA_ACTIVIDADES_REALIZADAS, TIPO_DE_RED, PUNTA_CI, MARCA, MODELO, sitio_correcto_cat, cliente_correcto_cat, AÑO, MES, SEMANA, DIA, HORA, RESPONSABLE, SITIOS_CRITICOS, SITIOS_PENALIZABLES, SLA_CONTRATO_CI, SLA_CONTRATO_PUNTA, SLA_CONTRATO, UDN, REGION, SEGMENTO, PLAZA DE VENTA]
# Index: []
#
# [0 rows x 53 columns]

# %%
df_master[df_master['REF_NUM']==1131010]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, NOMBRE, ZES_PROACTIVO_REACTIVO, SERVICIO_AFECTADO, FALLA, ESTATUS, MOTIVO, GRUPO_ACTUAL, PRIORIDAD, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, DURACION, DIAGNOSTICO, SOLUCION, AREA_RESOLUTORA, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, AFECTACION_DE_SERVICIO, RESUMEN, DESCRIPCION, TICKET_SISTEMA_EXTERNO, REGION_CIUDAD, TICKET_PADRE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, CLIENTE_CI, CLIENTE_CMDB, IP_CMDB, TIEMPO_ACTIVIDAD, DIAGNOSTICO_INCIAL, FECHA_HORA_ACTIVIDADES_REALIZADAS, TIPO_DE_RED, PUNTA_CI, MARCA, MODELO, sitio_correcto_cat, cliente_correcto_cat, AÑO, MES, SEMANA, DIA, HORA, RESPONSABLE, SITIOS_CRITICOS, SITIOS_PENALIZABLES, SLA_CONTRATO_CI, SLA_CONTRATO_PUNTA, SLA_CONTRATO, UDN, REGION, SEGMENTO, PLAZA DE VENTA]
# Index: []
#
# [0 rows x 53 columns]

# %%
df_master.groupby('AFECTACION_DE_SERVICIO')['REF_NUM'].count()
# Out:
# AFECTACION_DE_SERVICIO
# NO       631
# SI    130461
# Name: REF_NUM, dtype: int64

# %%
df_pretickets.REF_NUM.count() + df_null.REF_NUM.count()
# Out:
# 285161

# %%
# #Calculo para desviación de tiempo de asistencia ECCC
# #df_asistencias = gc.open('Control de asistencia ECCC').add_worksheet(title="Hoja 5", rows=0, cols=0)
# df_asistencias_09 = gc.open('Control de asistencia ECCC').worksheet("septiembre")
# df_asistencias_10 = gc.open('Control de asistencia ECCC').worksheet("octubre")
# df_asistencias_09 = df_asistencias_09.get_all_records(head=1)
# df_asistencias_10 = df_asistencias_10.get_all_records(head=1)
# df_asistencias_09 = pd.DataFrame(df_asistencias_09)
# df_asistencias_10 = pd.DataFrame(df_asistencias_10)

# %%
# df_asistencias_09 = df_asistencias_09.melt(id_vars=['Lider','Nombre','# de empleado','Horario','H.Entrada'], var_name='Fecha', value_name='Llegada')
# df_asistencias_09['Llegada_str'] = df_asistencias_09['Llegada']
# df_asistencias_09['Llegada'] = np.where(((df_asistencias_09['Llegada'] =='V') | (df_asistencias_09['Llegada'] =='H')), df_asistencias_09['H.Entrada'], df_asistencias_09['Llegada'])
# df_asistencias_09['Llegada'] = pd.to_timedelta(pd.to_datetime(df_asistencias_09['Llegada']).dt.strftime('%H:%M:%S'))
# df_asistencias_09['H.Entrada'] = pd.to_timedelta(pd.to_datetime(df_asistencias_09['H.Entrada']).dt.strftime('%H:%M:%S'))
# #df_asistencias_09['Llegada'] = df_asistencias_09['Llegada'].fillna(pd.Timedelta(seconds=0))
# df_asistencias_09.sort_values("Llegada", ascending=False).head()
# df_asistencias_09['TAF_TEC'] =  np.where(df_asistencias_09['Llegada'] != "00:00:00", df_asistencias_09.Llegada - df_asistencias_09['H.Entrada'], 0)
# df_asistencias_09['Llegada'] = df_asistencias_09['Llegada'].dt.total_seconds()
# df_asistencias_09['H.Entrada'] = df_asistencias_09['H.Entrada'].dt.total_seconds()
# df_asistencias_09['TAF_TEC'] = df_asistencias_09['TAF_TEC'].dt.total_seconds()
# df_asistencias_09 = df_asistencias_09.sort_values('TAF_TEC', ascending=False)
# df_asistencias_09.head()

# %%
# df_asistencias_09.head()

# %%
# df_asistencias_10 = df_asistencias_10.melt(id_vars=['Lider','Nombre','# de empleado','Horario','H.Entrada'], var_name='Fecha', value_name='Llegada')
# df_asistencias_10['Llegada_str'] = df_asistencias_10['Llegada']
# df_asistencias_10['Llegada'] = np.where(((df_asistencias_10['Llegada'] =='V') | (df_asistencias_10['Llegada'] =='H')), df_asistencias_10['H.Entrada'], df_asistencias_10['Llegada'])
# df_asistencias_10['Llegada'] = pd.to_timedelta(pd.to_datetime(df_asistencias_10['Llegada']).dt.strftime('%H:%M:%S'))
# df_asistencias_10['H.Entrada'] = pd.to_timedelta(pd.to_datetime(df_asistencias_10['H.Entrada']).dt.strftime('%H:%M:%S'))
# #df_asistencias['Llegada'] = df_asistencias['Llegada'].fillna(pd.Timedelta(seconds=0))
# df_asistencias_10.sort_values("Llegada", ascending=False).head()
# df_asistencias_10['TAF_TEC'] =  np.where(df_asistencias_10['Llegada'] != "00:00:00", df_asistencias_10.Llegada - df_asistencias_10['H.Entrada'], 0)
# df_asistencias_10['Llegada'] = df_asistencias_10['Llegada'].dt.total_seconds()
# df_asistencias_10['H.Entrada'] = df_asistencias_10['H.Entrada'].dt.total_seconds()
# df_asistencias_10['TAF_TEC'] = df_asistencias_10['TAF_TEC'].dt.total_seconds()
# df_asistencias_10 = df_asistencias_10.sort_values('TAF_TEC', ascending=False)
# df_asistencias_10.head()

# %%
# df_asistencias = pd.concat([df_asistencias_09, df_asistencias_10])
# df_asistencias.head()

# %%
# #spreadsheet19 = gc.open('Lista de asistencia').add_worksheet(title="concentrado", rows=0, cols=0)
# spreadsheet19 = gc.open('Control de asistencia ECCC').worksheet("concentrado")
# spreadsheet19.clear()
# gd.set_with_dataframe(spreadsheet19, df_asistencias, row=1, col=1, include_index=False, include_column_header=True)

# %%
# #spreadsheet20 = gc.open('Cambios_Conciliaciones').add_worksheet(title="Reg_Ori", rows=0, cols=0)
# #spreadsheet21 = gc.open('Cambios_Conciliaciones').add_worksheet(title="Reg_Mod", rows=0, cols=0)
spreadsheet20 = gc.open('Cambios_Conciliaciones').worksheet("Reg_Ori")
spreadsheet21 = gc.open('Cambios_Conciliaciones').worksheet("Reg_Mod")
spreadsheet20.clear()
spreadsheet21.clear()
gd.set_with_dataframe(spreadsheet20, df_reg_ori, row=1, col=1, include_index=False, include_column_header=True)
gd.set_with_dataframe(spreadsheet21, df_reg_mod, row=1, col=1, include_index=False, include_column_header=True)

# %%
# # sh22 = gc.create('sitios_fuera_sem')
# # spreadsheet22 = gc.open('sitios_fuera_sem').add_worksheet(title="sitios_fuera_sem", rows=0, cols=0)
# spreadsheet22 = gc.open('sitios_fuera_sem').worksheet("sitios_fuera_sem")
# spreadsheet22.clear()
# gd.set_with_dataframe(spreadsheet22, df_sitios_fuera_sem, row=1, col=1, include_index=False, include_column_header=True)

# %%
#df_master.groupby(['DIAGNOSTICO','SOLUCION'])['REF_NUM'].count().reset_index().to_csv('DIAGNOSTICO_SOLUCION.csv', encoding='latin-1', index=False)
#df_master['GRUPO'] = ''
#df_master['VERTICAL'] = ''
#cat_grupo = gc.open('CAT_SITIOS_2021CI_').worksheet("CAT_CI")
#cat_vertical = gc.open('CAT_SITIOS_2021CI_').worksheet("CAT_IMPLE")

#df_sitios_corregir = df_sitios_corregir.get_all_records(head=1)
#df_sitios_corregir = pd.DataFrame(df_sitios_corregir)

#cat_vertical.groupby('Vertical')['Vertical'].count()
#cat_vertical.rename(columns={'VAGO721222AL5':'CLIENTE_CMDB'}, inplace=True)
# Obtener la vertical de catalogo y agregarla a df_master
#df_master = pd.merge(df_master, cat_vertical.loc[:,['CLIENTE_CMDB','Vertical']], how='left', on= ['CLIENTE_CMDB'])

# %%
# sh23 = gc.create('Clientes_Puntas_Segmentos')
# spreadsheet23 = gc.open('Clientes_Puntas_Segmentos').add_worksheet(title="Segmentos", rows=0, cols=0)
spreadsheet23 = gc.open('Clientes_UDN_Segmentos').worksheet("UDN_Segmentos")
spreadsheet23.clear()
df_Cat_Segmentos = df_master.groupby(['CLIENTE_CI','AÑO','MES','UDN','REGION','SEGMENTO','PLAZA DE VENTA','RESPONSABLE'])['REF_NUM'].count().reset_index()
df_Cat_Segmentos = df_Cat_Segmentos.rename(columns={'REF_NUM':'TTs'})
gd.set_with_dataframe(spreadsheet23, df_Cat_Segmentos, row=1, col=1, include_index=False, include_column_header=True)

# %%
df_Cat_Segmentos.head()
# Out:
#            CLIENTE_CI   AÑO  MES UDN REGION SEGMENTO PLAZA DE VENTA  \
# 0                      2023   12   -      -        -              -
# 1                      2023   12   -      -        -              -
# 2                      2024    2   -      -        -              -
# 3                      2024    4   -      -        -              -
# 4   Comentarios: test  2024    5   -      -        -              -
#
#   RESPONSABLE  TTs
# 0     CLIENTE    2
# 1   TOTALPLAY    2
# 2     CLIENTE    2
# 3     CLIENTE    2
# 4     CLIENTE    1

# %%
df_master[df_master['REF_NUM']==1660963]
# Out:
# Empty DataFrame
# Columns: [REF_NUM, NOMBRE, ZES_PROACTIVO_REACTIVO, SERVICIO_AFECTADO, FALLA, ESTATUS, MOTIVO, GRUPO_ACTUAL, PRIORIDAD, FECHA_INICIO, FECHA_HORA_NOTIF_SOLUCION, FECHA_CIERRE, DURACION, DIAGNOSTICO, SOLUCION, AREA_RESOLUTORA, TIEMPO_FALLA_CTE, TIEMPO_FALLA_TPE, AFECTACION_DE_SERVICIO, RESUMEN, DESCRIPCION, TICKET_SISTEMA_EXTERNO, REGION_CIUDAD, TICKET_PADRE, TIEMPO_FALLA_PROVEEDOR, TIEMPO_FALLA_TERCEROS, CLIENTE_CI, CLIENTE_CMDB, IP_CMDB, TIEMPO_ACTIVIDAD, DIAGNOSTICO_INCIAL, FECHA_HORA_ACTIVIDADES_REALIZADAS, TIPO_DE_RED, PUNTA_CI, MARCA, MODELO, sitio_correcto_cat, cliente_correcto_cat, AÑO, MES, SEMANA, DIA, HORA, RESPONSABLE, SITIOS_CRITICOS, SITIOS_PENALIZABLES, SLA_CONTRATO_CI, SLA_CONTRATO_PUNTA, SLA_CONTRATO, UDN, REGION, SEGMENTO, PLAZA DE VENTA]
# Index: []
#
# [0 rows x 53 columns]

# %%
df_TP_Sitios_Disp.head()
# Out:
#                       CLIENTE_CI  \
# 0  AT&T COMUNICACIONES DIGITALES
# 1     AUTO PARTES Y MAS SA DE CV
# 2     AUTO PARTES Y MAS SA DE CV
# 3     AUTO PARTES Y MAS SA DE CV
# 4                    BANAMEX ATM
#
#                                         CLIENTE_CMDB   AÑO  MES  TOTAL_TIME  \
# 0  GS-D-VPN50845_550226_Pabellon_Acapulco_AT&T Ti...  2023   12   3020399.0
# 1                        200193098_AUTO PARTES Y MAS  2023   12   3020399.0
# 2                         AUTO PARTES Y MAS SA DE CV  2023   12   3041166.0
# 3                        AUTO PARTES Y MAS, SA DE CV  2023   12   3020399.0
# 4  0200472005_D-MPLS82707_BANAMEX_ID_1833_CONVENC...  2023   12   3020399.0
#
#    TIEMPO_FALLA_PROVEEDOR  SITIOS_CRITICOS  SITIOS_PENALIZABLES  SLA_CONTRATO  \
# 0                     0.0              0.0                  0.0         99.95
# 1                     0.0              0.0                  1.0         99.40
# ...

# %%
df_sitios_fuera_3_meses = df_TP_Sitios_Disp[df_TP_Sitios_Disp['SLA'] == 'FUERA']
df_sitios_fuera_3_meses = df_sitios_fuera_3_meses[(df_sitios_fuera_3_meses['AÑO'] >= 2022)]
df_sitios_fuera_3_meses = df_sitios_fuera_3_meses[['CLIENTE_CI','CLIENTE_CMDB','AÑO','MES','TOTAL_TIME','TIEMPO_FALLA_PROVEEDOR','SLA_CONTRATO','TOTAL_TICKETs','TICKETs','DISPONIBILIDAD','SLA']]
df_sitios_fuera_3_meses['SLA_CONTRATO'] = df_sitios_fuera_3_meses['SLA_CONTRATO']/100
df_sitios_fuera_3_meses['DISPONIBILIDAD'] = df_sitios_fuera_3_meses['DISPONIBILIDAD']/100

# %%
df_sitios_fuera_3_meses[df_sitios_fuera_3_meses['CLIENTE_CMDB'] =='TFE-D-IS45597_WIRELESS_BRIDGE_TEPETITLAN']
# Out:
# Empty DataFrame
# Columns: [CLIENTE_CI, CLIENTE_CMDB, AÑO, MES, TOTAL_TIME, TIEMPO_FALLA_PROVEEDOR, SLA_CONTRATO, TOTAL_TICKETs, TICKETs, DISPONIBILIDAD, SLA]
# Index: []

# %%
df_frec_fuera_sla = df_sitios_fuera_3_meses.reset_index().groupby(['CLIENTE_CI','CLIENTE_CMDB'])['CLIENTE_CMDB'].count().reset_index(name='FREC_FUERA_SLA')

# %%
df_sitios_fuera_3_meses = pd.merge(df_sitios_fuera_3_meses, df_frec_fuera_sla.loc[:, ['CLIENTE_CI','CLIENTE_CMDB','FREC_FUERA_SLA']], how='left', on=['CLIENTE_CI','CLIENTE_CMDB'])

# %%
df_sitios_fuera_3_meses = df_sitios_fuera_3_meses[(df_sitios_fuera_3_meses['FREC_FUERA_SLA'] == 3) & (df_sitios_fuera_3_meses['AÑO'] == 2022)]

# %%
df_sitios_fuera_3_meses.head()
# Out:
# Empty DataFrame
# Columns: [CLIENTE_CI, CLIENTE_CMDB, AÑO, MES, TOTAL_TIME, TIEMPO_FALLA_PROVEEDOR, SLA_CONTRATO, TOTAL_TICKETs, TICKETs, DISPONIBILIDAD, SLA, FREC_FUERA_SLA]
# Index: []

# %%
# sh24 = gc.create('Sitios Fuera SLA 3 meses')
# spreadsheet24 = gc.open('Sitios Fuera SLA 3 meses').add_worksheet(title="Sitios Fuera SLA 3 meses", rows=0, cols=0)
spreadsheet24 = gc.open('Sitios Fuera SLA 3 meses').worksheet("Sitios Fuera SLA 3 meses")
spreadsheet24.clear()
gd.set_with_dataframe(spreadsheet24, df_sitios_fuera_3_meses, row=1, col=1, include_index=False, include_column_header=True)

# %%
#tiempo_final = time()
#tiempo_ejecucion = (tiempo_final - tiempo_inicial) / 60
#print ('!Procesamiento exitoso!, el tiempo de ejecucion fue de:'),tiempo_ejecucion,  "minutos" #En Minutos

# %%
#import datetime
#now = datetime.datetime.now()
#now.month

#df_Detalles_Incidentes_2021 = df_Detalles_Incidentes_2021[df_Detalles_Incidentes_2021['MES'] >= now.month]

#df_Detalles_Incidentes_Gral = pd.concat([df_Detalles_Incidentes_2021, df_Detalles_Incidentes_2022])

# %%
#gd.set_with_dataframe(spreadsheetGral, df_Detalles_Incidentes_Gral, row=1, col=1, include_index=False, include_column_header=True) #Se separan por mes ignorar esta línea
